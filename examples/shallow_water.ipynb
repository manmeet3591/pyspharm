# %%
#!/usr/bin/python

## "non-linear barotropically unstable shallow water test case"
## example provided by Jeffrey Whitaker
## https://gist.github.com/jswhit/3845307
##
## Running the script should pop up a window with this image:
## http://i.imgur.com/ZlxR1.png


import numpy as np
import shtns

class Spharmt(object):
	"""
	wrapper class for commonly used spectral transform operations in
	atmospheric models.  Provides an interface to shtns compatible
	with pyspharm (pyspharm.googlecode.com).
	"""
	def __init__(self,nlons,nlats,ntrunc,rsphere,gridtype='gaussian'):
		"""initialize
		nlons:  number of longitudes
		nlats:  number of latitudes"""
		self._shtns = shtns.sht(ntrunc, ntrunc, 1, \
								shtns.sht_orthonormal+shtns.SHT_NO_CS_PHASE)
		if gridtype == 'gaussian':
			#self._shtns.set_grid(nlats,nlons,shtns.sht_gauss_fly|shtns.SHT_PHI_CONTIGUOUS,1.e-10)
			self._shtns.set_grid(nlats,nlons,shtns.sht_quick_init|shtns.SHT_PHI_CONTIGUOUS,1.e-10)
		elif gridtype == 'regular':
			self._shtns.set_grid(nlats,nlons,shtns.sht_reg_dct|shtns.SHT_PHI_CONTIGUOUS,1.e-10)
		self.lats = np.arcsin(self._shtns.cos_theta)
		self.lons = (2.*np.pi/nlons)*np.arange(nlons)
		self.nlons = nlons
		self.nlats = nlats
		self.ntrunc = ntrunc
		self.nlm = self._shtns.nlm
		self.degree = self._shtns.l
		self.lap = -self.degree*(self.degree+1.0).astype(np.complex)
		self.invlap = np.zeros(self.lap.shape, self.lap.dtype)
		self.invlap[1:] = 1./self.lap[1:]
		self.rsphere = rsphere
		self.lap = self.lap/rsphere**2
		self.invlap = self.invlap*rsphere**2
	def grdtospec(self,data):
		"""compute spectral coefficients from gridded data"""
		return self._shtns.analys(data)
	def spectogrd(self,dataspec):
		"""compute gridded data from spectral coefficients"""
		return self._shtns.synth(dataspec)
	def getuv(self,vrtspec,divspec):
		"""compute wind vector from spectral coeffs of vorticity and divergence"""
		return self._shtns.synth((self.invlap/self.rsphere)*vrtspec, (self.invlap/self.rsphere)*divspec)
	def getvrtdivspec(self,u,v):
		"""compute spectral coeffs of vorticity and divergence from wind vector"""
		vrtspec, divspec = self._shtns.analys(u, v)
		return self.lap*self.rsphere*vrtspec, self.lap*rsphere*divspec
	def getgrad(self,divspec):
		"""compute gradient vector from spectral coeffs"""
		vrtspec = np.zeros(divspec.shape, dtype=np.complex)
		u,v = self._shtns.synth(vrtspec,divspec)
		return u/rsphere, v/rsphere

if __name__ == "__main__":
    import matplotlib.pyplot as plt
    import time

    # non-linear barotropically unstable shallow water test case
    # of Galewsky et al (2004, Tellus, 56A, 429-440).
    # "An initial-value problem for testing numerical models of the global
    # shallow-water equations" DOI: 10.1111/j.1600-0870.2004.00071.x
    # http://www-vortex.mcs.st-and.ac.uk/~rks/reprints/galewsky_etal_tellus_2004.pdf
    
    # requires matplotlib for plotting.

    # grid, time step info
    nlons = 256  # number of longitudes
    ntrunc = int(nlons/3)  # spectral truncation (for alias-free computations)
    nlats = int(nlons/2)   # for gaussian grid.
    dt = 150 # time step in seconds
    itmax = 6*int(86400/dt) # integration length in days

    # parameters for test
    rsphere = 6.37122e6 # earth radius
    omega = 7.292e-5 # rotation rate
    grav = 9.80616 # gravity
    hbar = 10.e3 # resting depth
    umax = 80. # jet speed
    phi0 = np.pi/7.; phi1 = 0.5*np.pi - phi0; phi2 = 0.25*np.pi
    en = np.exp(-4.0/(phi1-phi0)**2)
    alpha = 1./3.; beta = 1./15.
    hamp = 120. # amplitude of height perturbation to zonal jet
    efold = 3.*3600. # efolding timescale at ntrunc for hyperdiffusion
    ndiss = 8 # order for hyperdiffusion

    # setup up spherical harmonic instance, set lats/lons of grid
    x = Spharmt(nlons,nlats,ntrunc,rsphere,gridtype='gaussian')
    lons,lats = np.meshgrid(x.lons, x.lats)
    f = 2.*omega*np.sin(lats) # coriolis

    # zonal jet.
    vg = np.zeros((nlats,nlons),np.float)
    u1 = (umax/en)*np.exp(1./((x.lats-phi0)*(x.lats-phi1)))
    ug = np.zeros((nlats),np.float)
    ug = np.where(np.logical_and(x.lats < phi1, x.lats > phi0), u1, ug)
    ug.shape = (nlats,1)
    ug = ug*np.ones((nlats,nlons),dtype=np.float) # broadcast to shape (nlats,nlonss)
    # height perturbation.
    hbump = hamp*np.cos(lats)*np.exp(-(lons/alpha)**2)*np.exp(-(phi2-lats)**2/beta)

    # initial vorticity, divergence in spectral space
    vrtspec, divspec =  x.getvrtdivspec(ug,vg)
    vrtg = x.spectogrd(vrtspec)
    divg = x.spectogrd(divspec)

    # create hyperdiffusion factor
    hyperdiff_fact = np.exp((-dt/efold)*(x.lap/x.lap[-1])**(ndiss/2))

    # solve nonlinear balance eqn to get initial zonal geopotential,
    # add localized bump (not balanced).
    vrtg = x.spectogrd(vrtspec)
    tmpg1 = ug*(vrtg+f); tmpg2 = vg*(vrtg+f)
    tmpspec1, tmpspec2 = x.getvrtdivspec(tmpg1,tmpg2)
    tmpspec2 = x.grdtospec(0.5*(ug**2+vg**2))
    phispec = x.invlap*tmpspec1 - tmpspec2
    phig = grav*(hbar + hbump) + x.spectogrd(phispec)
    phispec = x.grdtospec(phig)

    # initialize spectral tendency arrays
    ddivdtspec = np.zeros(vrtspec.shape+(3,), np.complex)
    dvrtdtspec = np.zeros(vrtspec.shape+(3,), np.complex)
    dphidtspec = np.zeros(vrtspec.shape+(3,), np.complex)
    nnew = 0; nnow = 1; nold = 2

    # time loop.
    time1 = time.clock()
    for ncycle in range(itmax+1):
        t = ncycle*dt
        # get vort,u,v,phi on grid
        vrtg = x.spectogrd(vrtspec)
        ug,vg = x.getuv(vrtspec,divspec)
        phig = x.spectogrd(phispec)
        print('t=%6.2f hours: min/max %6.2f, %6.2f' % (t/3600.,vg.min(), vg.max()))
        # compute tendencies.
        tmpg1 = ug*(vrtg+f); tmpg2 = vg*(vrtg+f)
        ddivdtspec[:,nnew], dvrtdtspec[:,nnew] = x.getvrtdivspec(tmpg1,tmpg2)
        dvrtdtspec[:,nnew] *= -1
        tmpg = x.spectogrd(ddivdtspec[:,nnew])
        tmpg1 = ug*phig; tmpg2 = vg*phig
        tmpspec, dphidtspec[:,nnew] = x.getvrtdivspec(tmpg1,tmpg2)
        dphidtspec[:,nnew] *= -1
        tmpspec = x.grdtospec(phig+0.5*(ug**2+vg**2))
        ddivdtspec[:,nnew] += -x.lap*tmpspec
        # update vort,div,phiv with third-order adams-bashforth.
        # forward euler, then 2nd-order adams-bashforth time steps to start.
        if ncycle == 0:
            dvrtdtspec[:,nnow] = dvrtdtspec[:,nnew]
            dvrtdtspec[:,nold] = dvrtdtspec[:,nnew]
            ddivdtspec[:,nnow] = ddivdtspec[:,nnew]
            ddivdtspec[:,nold] = ddivdtspec[:,nnew]
            dphidtspec[:,nnow] = dphidtspec[:,nnew]
            dphidtspec[:,nold] = dphidtspec[:,nnew]
        elif ncycle == 1:
            dvrtdtspec[:,nold] = dvrtdtspec[:,nnew]
            ddivdtspec[:,nold] = ddivdtspec[:,nnew]
            dphidtspec[:,nold] = dphidtspec[:,nnew]
        vrtspec += dt*( \
        (23./12.)*dvrtdtspec[:,nnew] - (16./12.)*dvrtdtspec[:,nnow]+ \
        (5./12.)*dvrtdtspec[:,nold] )
        divspec += dt*( \
        (23./12.)*ddivdtspec[:,nnew] - (16./12.)*ddivdtspec[:,nnow]+ \
        (5./12.)*ddivdtspec[:,nold] )
        phispec += dt*( \
        (23./12.)*dphidtspec[:,nnew] - (16./12.)*dphidtspec[:,nnow]+ \
        (5./12.)*dphidtspec[:,nold] )
        # implicit hyperdiffusion for vort and div.
        vrtspec *= hyperdiff_fact
        divspec *= hyperdiff_fact
        # switch indices, do next time step.
        nsav1 = nnew; nsav2 = nnow
        nnew = nold; nnow = nsav1; nold = nsav2

    time2 = time.clock()
    print('CPU time = ',time2-time1)

    # make a contour plot of potential vorticity in the Northern Hem.
    fig = plt.figure(figsize=(12,4))
    # dimensionless PV
    pvg = (0.5*hbar*grav/omega)*(vrtg+f)/phig
    print('max/min PV',pvg.min(), pvg.max())
    lons1d = (180./np.pi)*x.lons-180.; lats1d = (180./np.pi)*x.lats
    levs = np.arange(-0.2,1.801,0.1)
    cs=plt.contourf(lons1d,lats1d,pvg,levs,cmap=plt.cm.get_cmap("Spectral"),extend='both')
    cb=plt.colorbar(cs,orientation='horizontal') # add colorbar
    cb.set_label('potential vorticity')
    plt.grid()
    plt.xlabel('degrees longitude')
    plt.ylabel('degrees latitude')
    plt.xticks(np.arange(-180,181,60))
    plt.yticks(np.arange(-5,81,20))
    plt.axis('equal')
    plt.axis('tight')
    plt.ylim(0,lats1d[0])
    plt.title('PV (T%s with hyperdiffusion, hour %6.2f)' % (ntrunc,t/3600.))
    plt.show()
# Out:
# t=  0.00 hours: min/max   0.00,   0.00
# t=  0.04 hours: min/max  -0.07,   0.07
# t=  0.08 hours: min/max  -0.15,   0.15
# t=  0.12 hours: min/max  -0.21,   0.21
# t=  0.17 hours: min/max  -0.27,   0.27
# t=  0.21 hours: min/max  -0.33,   0.33
# t=  0.25 hours: min/max  -0.39,   0.37
# t=  0.29 hours: min/max  -0.45,   0.43
# t=  0.33 hours: min/max  -0.49,   0.47
# t=  0.38 hours: min/max  -0.55,   0.52
# t=  0.42 hours: min/max  -0.59,   0.55
# t=  0.46 hours: min/max  -0.63,   0.58
# t=  0.50 hours: min/max  -0.67,   0.61
# t=  0.54 hours: min/max  -0.70,   0.63
# t=  0.58 hours: min/max  -0.73,   0.66
# t=  0.62 hours: min/max  -0.76,   0.70
# t=  0.67 hours: min/max  -0.77,   0.73
# t=  0.71 hours: min/max  -0.80,   0.76
# t=  0.75 hours: min/max  -0.81,   0.80
# t=  0.79 hours: min/max  -0.82,   0.83
# t=  0.83 hours: min/max  -0.84,   0.86
# t=  0.88 hours: min/max  -0.84,   0.88
# t=  0.92 hours: min/max  -0.86,   0.89
# t=  0.96 hours: min/max  -0.86,   0.91
# t=  1.00 hours: min/max  -0.87,   0.93
# t=  1.04 hours: min/max  -0.87,   0.93
# t=  1.08 hours: min/max  -0.87,   0.93
# t=  1.12 hours: min/max  -0.87,   0.94
# t=  1.17 hours: min/max  -0.86,   0.95
# t=  1.21 hours: min/max  -0.87,   0.94
# t=  1.25 hours: min/max  -0.86,   0.94
# t=  1.29 hours: min/max  -0.86,   0.93
# t=  1.33 hours: min/max  -0.85,   0.93
# t=  1.38 hours: min/max  -0.85,   0.92
# t=  1.42 hours: min/max  -0.84,   0.90
# t=  1.46 hours: min/max  -0.84,   0.89
# t=  1.50 hours: min/max  -0.83,   0.87
# t=  1.54 hours: min/max  -0.84,   0.85
# t=  1.58 hours: min/max  -0.82,   0.83
# t=  1.62 hours: min/max  -0.82,   0.81
# t=  1.67 hours: min/max  -0.81,   0.79
# t=  1.71 hours: min/max  -0.81,   0.77
# t=  1.75 hours: min/max  -0.80,   0.74
# t=  1.79 hours: min/max  -0.80,   0.72
# t=  1.83 hours: min/max  -0.79,   0.70
# t=  1.88 hours: min/max  -0.79,   0.67
# t=  1.92 hours: min/max  -0.78,   0.66
# t=  1.96 hours: min/max  -0.77,   0.65
# t=  2.00 hours: min/max  -0.77,   0.63
# t=  2.04 hours: min/max  -0.76,   0.63
# t=  2.08 hours: min/max  -0.76,   0.62
# t=  2.12 hours: min/max  -0.75,   0.61
# t=  2.17 hours: min/max  -0.75,   0.61
# t=  2.21 hours: min/max  -0.74,   0.60
# t=  2.25 hours: min/max  -0.74,   0.59
# t=  2.29 hours: min/max  -0.73,   0.59
# t=  2.33 hours: min/max  -0.73,   0.58
# t=  2.38 hours: min/max  -0.72,   0.57
# t=  2.42 hours: min/max  -0.72,   0.57
# t=  2.46 hours: min/max  -0.70,   0.56
# t=  2.50 hours: min/max  -0.71,   0.56
# t=  2.54 hours: min/max  -0.70,   0.56
# t=  2.58 hours: min/max  -0.70,   0.55
# t=  2.62 hours: min/max  -0.69,   0.55
# t=  2.67 hours: min/max  -0.69,   0.55
# t=  2.71 hours: min/max  -0.68,   0.54
# t=  2.75 hours: min/max  -0.68,   0.54
# t=  2.79 hours: min/max  -0.68,   0.54
# t=  2.83 hours: min/max  -0.67,   0.53
# t=  2.88 hours: min/max  -0.67,   0.53
# t=  2.92 hours: min/max  -0.67,   0.53
# t=  2.96 hours: min/max  -0.66,   0.52
# t=  3.00 hours: min/max  -0.66,   0.52
# t=  3.04 hours: min/max  -0.66,   0.52
# t=  3.08 hours: min/max  -0.65,   0.52
# t=  3.12 hours: min/max  -0.65,   0.52
# t=  3.17 hours: min/max  -0.64,   0.52
# t=  3.21 hours: min/max  -0.65,   0.51
# t=  3.25 hours: min/max  -0.63,   0.51
# t=  3.29 hours: min/max  -0.64,   0.52
# t=  3.33 hours: min/max  -0.63,   0.51
# t=  3.38 hours: min/max  -0.63,   0.51
# t=  3.42 hours: min/max  -0.62,   0.51
# t=  3.46 hours: min/max  -0.62,   0.51
# t=  3.50 hours: min/max  -0.62,   0.51
# t=  3.54 hours: min/max  -0.62,   0.51
# t=  3.58 hours: min/max  -0.61,   0.50
# t=  3.62 hours: min/max  -0.61,   0.50
# t=  3.67 hours: min/max  -0.61,   0.51
# t=  3.71 hours: min/max  -0.60,   0.50
# t=  3.75 hours: min/max  -0.60,   0.50
# t=  3.79 hours: min/max  -0.59,   0.50
# t=  3.83 hours: min/max  -0.60,   0.50
# t=  3.88 hours: min/max  -0.59,   0.50
# t=  3.92 hours: min/max  -0.59,   0.50
# t=  3.96 hours: min/max  -0.58,   0.50
# t=  4.00 hours: min/max  -0.59,   0.50
# t=  4.04 hours: min/max  -0.58,   0.50
# t=  4.08 hours: min/max  -0.58,   0.50
# t=  4.12 hours: min/max  -0.58,   0.50
# t=  4.17 hours: min/max  -0.57,   0.49
# t=  4.21 hours: min/max  -0.58,   0.50
# t=  4.25 hours: min/max  -0.57,   0.50
# t=  4.29 hours: min/max  -0.57,   0.49
# t=  4.33 hours: min/max  -0.56,   0.50
# t=  4.38 hours: min/max  -0.56,   0.50
# t=  4.42 hours: min/max  -0.56,   0.49
# t=  4.46 hours: min/max  -0.56,   0.50
# t=  4.50 hours: min/max  -0.56,   0.50
# t=  4.54 hours: min/max  -0.56,   0.50
# t=  4.58 hours: min/max  -0.55,   0.50
# t=  4.62 hours: min/max  -0.55,   0.50
# t=  4.67 hours: min/max  -0.55,   0.50
# t=  4.71 hours: min/max  -0.54,   0.50
# t=  4.75 hours: min/max  -0.55,   0.50
# t=  4.79 hours: min/max  -0.54,   0.50
# t=  4.83 hours: min/max  -0.54,   0.51
# t=  4.88 hours: min/max  -0.53,   0.51
# t=  4.92 hours: min/max  -0.54,   0.50
# t=  4.96 hours: min/max  -0.53,   0.51
# t=  5.00 hours: min/max  -0.53,   0.50
# t=  5.04 hours: min/max  -0.53,   0.51
# t=  5.08 hours: min/max  -0.53,   0.51
# t=  5.12 hours: min/max  -0.53,   0.50
# t=  5.17 hours: min/max  -0.53,   0.51
# t=  5.21 hours: min/max  -0.53,   0.51
# t=  5.25 hours: min/max  -0.53,   0.51
# t=  5.29 hours: min/max  -0.53,   0.51
# t=  5.33 hours: min/max  -0.53,   0.51
# t=  5.38 hours: min/max  -0.53,   0.51
# t=  5.42 hours: min/max  -0.54,   0.52
# t=  5.46 hours: min/max  -0.54,   0.51
# t=  5.50 hours: min/max  -0.54,   0.51
# t=  5.54 hours: min/max  -0.54,   0.52
# t=  5.58 hours: min/max  -0.54,   0.51
# t=  5.62 hours: min/max  -0.54,   0.51
# t=  5.67 hours: min/max  -0.55,   0.52
# t=  5.71 hours: min/max  -0.55,   0.52
# t=  5.75 hours: min/max  -0.55,   0.51
# t=  5.79 hours: min/max  -0.55,   0.52
# t=  5.83 hours: min/max  -0.55,   0.52
# t=  5.88 hours: min/max  -0.55,   0.52
# t=  5.92 hours: min/max  -0.55,   0.52
# t=  5.96 hours: min/max  -0.55,   0.52
# t=  6.00 hours: min/max  -0.56,   0.52
# t=  6.04 hours: min/max  -0.56,   0.52
# t=  6.08 hours: min/max  -0.56,   0.51
# t=  6.12 hours: min/max  -0.56,   0.52
# t=  6.17 hours: min/max  -0.56,   0.52
# t=  6.21 hours: min/max  -0.56,   0.51
# t=  6.25 hours: min/max  -0.56,   0.52
# t=  6.29 hours: min/max  -0.56,   0.52
# t=  6.33 hours: min/max  -0.56,   0.52
# t=  6.38 hours: min/max  -0.57,   0.52
# t=  6.42 hours: min/max  -0.57,   0.52
# t=  6.46 hours: min/max  -0.57,   0.52
# t=  6.50 hours: min/max  -0.57,   0.52
# t=  6.54 hours: min/max  -0.57,   0.52
# t=  6.58 hours: min/max  -0.57,   0.52
# t=  6.62 hours: min/max  -0.57,   0.52
# t=  6.67 hours: min/max  -0.57,   0.51
# t=  6.71 hours: min/max  -0.57,   0.52
# t=  6.75 hours: min/max  -0.57,   0.52
# t=  6.79 hours: min/max  -0.57,   0.51
# t=  6.83 hours: min/max  -0.57,   0.51
# t=  6.88 hours: min/max  -0.57,   0.52
# t=  6.92 hours: min/max  -0.57,   0.51
# t=  6.96 hours: min/max  -0.58,   0.51
# t=  7.00 hours: min/max  -0.58,   0.51
# t=  7.04 hours: min/max  -0.58,   0.51
# t=  7.08 hours: min/max  -0.57,   0.51
# t=  7.12 hours: min/max  -0.58,   0.51
# t=  7.17 hours: min/max  -0.58,   0.50
# t=  7.21 hours: min/max  -0.58,   0.51
# t=  7.25 hours: min/max  -0.57,   0.50
# t=  7.29 hours: min/max  -0.57,   0.50
# t=  7.33 hours: min/max  -0.58,   0.50
# t=  7.38 hours: min/max  -0.58,   0.50
# t=  7.42 hours: min/max  -0.58,   0.50
# t=  7.46 hours: min/max  -0.57,   0.50
# t=  7.50 hours: min/max  -0.58,   0.50
# t=  7.54 hours: min/max  -0.58,   0.50
# t=  7.58 hours: min/max  -0.58,   0.50
# t=  7.62 hours: min/max  -0.58,   0.49
# t=  7.67 hours: min/max  -0.58,   0.49
# t=  7.71 hours: min/max  -0.58,   0.49
# t=  7.75 hours: min/max  -0.58,   0.49
# t=  7.79 hours: min/max  -0.58,   0.49
# t=  7.83 hours: min/max  -0.57,   0.49
# t=  7.88 hours: min/max  -0.57,   0.48
# t=  7.92 hours: min/max  -0.58,   0.48
# t=  7.96 hours: min/max  -0.58,   0.49
# t=  8.00 hours: min/max  -0.58,   0.48
# t=  8.04 hours: min/max  -0.57,   0.48
# t=  8.08 hours: min/max  -0.58,   0.48
# t=  8.12 hours: min/max  -0.58,   0.47
# t=  8.17 hours: min/max  -0.58,   0.47
# t=  8.21 hours: min/max  -0.57,   0.47
# t=  8.25 hours: min/max  -0.57,   0.46
# t=  8.29 hours: min/max  -0.58,   0.46
# t=  8.33 hours: min/max  -0.57,   0.46
# t=  8.38 hours: min/max  -0.57,   0.45
# t=  8.42 hours: min/max  -0.57,   0.46
# t=  8.46 hours: min/max  -0.57,   0.45
# t=  8.50 hours: min/max  -0.57,   0.45
# t=  8.54 hours: min/max  -0.57,   0.45
# t=  8.58 hours: min/max  -0.57,   0.44
# t=  8.62 hours: min/max  -0.57,   0.44
# t=  8.67 hours: min/max  -0.57,   0.44
# t=  8.71 hours: min/max  -0.57,   0.43
# t=  8.75 hours: min/max  -0.57,   0.43
# t=  8.79 hours: min/max  -0.56,   0.43
# t=  8.83 hours: min/max  -0.57,   0.42
# t=  8.88 hours: min/max  -0.57,   0.42
# t=  8.92 hours: min/max  -0.56,   0.42
# t=  8.96 hours: min/max  -0.56,   0.41
# t=  9.00 hours: min/max  -0.56,   0.41
# t=  9.04 hours: min/max  -0.56,   0.41
# t=  9.08 hours: min/max  -0.56,   0.40
# t=  9.12 hours: min/max  -0.56,   0.40
# t=  9.17 hours: min/max  -0.56,   0.40
# t=  9.21 hours: min/max  -0.55,   0.39
# t=  9.25 hours: min/max  -0.56,   0.39
# t=  9.29 hours: min/max  -0.56,   0.38
# t=  9.33 hours: min/max  -0.55,   0.37
# t=  9.38 hours: min/max  -0.55,   0.37
# t=  9.42 hours: min/max  -0.55,   0.37
# t=  9.46 hours: min/max  -0.55,   0.36
# t=  9.50 hours: min/max  -0.55,   0.36
# t=  9.54 hours: min/max  -0.54,   0.36
# t=  9.58 hours: min/max  -0.55,   0.35
# t=  9.62 hours: min/max  -0.55,   0.35
# t=  9.67 hours: min/max  -0.54,   0.34
# t=  9.71 hours: min/max  -0.54,   0.34
# t=  9.75 hours: min/max  -0.54,   0.34
# t=  9.79 hours: min/max  -0.54,   0.35
# t=  9.83 hours: min/max  -0.54,   0.35
# t=  9.88 hours: min/max  -0.54,   0.35
# t=  9.92 hours: min/max  -0.54,   0.35
# t=  9.96 hours: min/max  -0.54,   0.35
# t= 10.00 hours: min/max  -0.54,   0.35
# t= 10.04 hours: min/max  -0.54,   0.35
# t= 10.08 hours: min/max  -0.54,   0.35
# t= 10.12 hours: min/max  -0.55,   0.35
# t= 10.17 hours: min/max  -0.55,   0.36
# t= 10.21 hours: min/max  -0.55,   0.36
# t= 10.25 hours: min/max  -0.55,   0.36
# t= 10.29 hours: min/max  -0.55,   0.36
# t= 10.33 hours: min/max  -0.55,   0.36
# t= 10.38 hours: min/max  -0.55,   0.36
# t= 10.42 hours: min/max  -0.55,   0.36
# t= 10.46 hours: min/max  -0.56,   0.36
# t= 10.50 hours: min/max  -0.56,   0.36
# t= 10.54 hours: min/max  -0.56,   0.36
# t= 10.58 hours: min/max  -0.56,   0.36
# t= 10.62 hours: min/max  -0.56,   0.37
# t= 10.67 hours: min/max  -0.56,   0.37
# t= 10.71 hours: min/max  -0.56,   0.37
# t= 10.75 hours: min/max  -0.56,   0.37
# t= 10.79 hours: min/max  -0.56,   0.37
# t= 10.83 hours: min/max  -0.56,   0.37
# t= 10.88 hours: min/max  -0.57,   0.37
# t= 10.92 hours: min/max  -0.57,   0.37
# t= 10.96 hours: min/max  -0.57,   0.37
# t= 11.00 hours: min/max  -0.57,   0.38
# t= 11.04 hours: min/max  -0.57,   0.38
# t= 11.08 hours: min/max  -0.57,   0.38
# t= 11.12 hours: min/max  -0.57,   0.38
# t= 11.17 hours: min/max  -0.57,   0.38
# t= 11.21 hours: min/max  -0.57,   0.38
# t= 11.25 hours: min/max  -0.57,   0.38
# t= 11.29 hours: min/max  -0.57,   0.38
# t= 11.33 hours: min/max  -0.57,   0.38
# t= 11.38 hours: min/max  -0.57,   0.39
# t= 11.42 hours: min/max  -0.58,   0.39
# t= 11.46 hours: min/max  -0.58,   0.39
# t= 11.50 hours: min/max  -0.58,   0.39
# t= 11.54 hours: min/max  -0.58,   0.39
# t= 11.58 hours: min/max  -0.58,   0.39
# t= 11.62 hours: min/max  -0.58,   0.39
# t= 11.67 hours: min/max  -0.58,   0.39
# t= 11.71 hours: min/max  -0.58,   0.39
# t= 11.75 hours: min/max  -0.58,   0.39
# t= 11.79 hours: min/max  -0.58,   0.39
# t= 11.83 hours: min/max  -0.58,   0.40
# t= 11.88 hours: min/max  -0.58,   0.39
# t= 11.92 hours: min/max  -0.58,   0.40
# t= 11.96 hours: min/max  -0.58,   0.40
# t= 12.00 hours: min/max  -0.58,   0.40
# t= 12.04 hours: min/max  -0.58,   0.40
# t= 12.08 hours: min/max  -0.58,   0.40
# t= 12.12 hours: min/max  -0.58,   0.40
# t= 12.17 hours: min/max  -0.58,   0.40
# t= 12.21 hours: min/max  -0.58,   0.40
# t= 12.25 hours: min/max  -0.58,   0.40
# t= 12.29 hours: min/max  -0.58,   0.40
# t= 12.33 hours: min/max  -0.58,   0.40
# t= 12.38 hours: min/max  -0.59,   0.41
# t= 12.42 hours: min/max  -0.59,   0.40
# t= 12.46 hours: min/max  -0.58,   0.41
# t= 12.50 hours: min/max  -0.59,   0.41
# t= 12.54 hours: min/max  -0.59,   0.41
# t= 12.58 hours: min/max  -0.59,   0.41
# t= 12.62 hours: min/max  -0.59,   0.41
# t= 12.67 hours: min/max  -0.59,   0.41
# t= 12.71 hours: min/max  -0.59,   0.41
# t= 12.75 hours: min/max  -0.59,   0.41
# t= 12.79 hours: min/max  -0.59,   0.41
# t= 12.83 hours: min/max  -0.59,   0.41
# t= 12.88 hours: min/max  -0.59,   0.41
# t= 12.92 hours: min/max  -0.59,   0.41
# t= 12.96 hours: min/max  -0.59,   0.41
# t= 13.00 hours: min/max  -0.59,   0.41
# t= 13.04 hours: min/max  -0.59,   0.41
# t= 13.08 hours: min/max  -0.59,   0.41
# t= 13.12 hours: min/max  -0.59,   0.41
# t= 13.17 hours: min/max  -0.59,   0.41
# t= 13.21 hours: min/max  -0.59,   0.41
# t= 13.25 hours: min/max  -0.59,   0.41
# t= 13.29 hours: min/max  -0.59,   0.41
# t= 13.33 hours: min/max  -0.59,   0.41
# t= 13.38 hours: min/max  -0.59,   0.41
# t= 13.42 hours: min/max  -0.59,   0.41
# t= 13.46 hours: min/max  -0.59,   0.41
# t= 13.50 hours: min/max  -0.60,   0.41
# t= 13.54 hours: min/max  -0.60,   0.41
# t= 13.58 hours: min/max  -0.60,   0.41
# t= 13.62 hours: min/max  -0.60,   0.41
# t= 13.67 hours: min/max  -0.60,   0.41
# t= 13.71 hours: min/max  -0.60,   0.41
# t= 13.75 hours: min/max  -0.60,   0.41
# t= 13.79 hours: min/max  -0.61,   0.41
# t= 13.83 hours: min/max  -0.61,   0.41
# t= 13.88 hours: min/max  -0.61,   0.41
# t= 13.92 hours: min/max  -0.61,   0.41
# t= 13.96 hours: min/max  -0.61,   0.41
# t= 14.00 hours: min/max  -0.61,   0.41
# t= 14.04 hours: min/max  -0.61,   0.40
# t= 14.08 hours: min/max  -0.61,   0.40
# t= 14.12 hours: min/max  -0.61,   0.40
# t= 14.17 hours: min/max  -0.61,   0.40
# t= 14.21 hours: min/max  -0.61,   0.40
# t= 14.25 hours: min/max  -0.62,   0.40
# t= 14.29 hours: min/max  -0.62,   0.40
# t= 14.33 hours: min/max  -0.62,   0.41
# t= 14.38 hours: min/max  -0.62,   0.41
# t= 14.42 hours: min/max  -0.62,   0.41
# t= 14.46 hours: min/max  -0.62,   0.41
# t= 14.50 hours: min/max  -0.62,   0.42
# t= 14.54 hours: min/max  -0.62,   0.42
# t= 14.58 hours: min/max  -0.62,   0.42
# t= 14.62 hours: min/max  -0.62,   0.43
# t= 14.67 hours: min/max  -0.63,   0.43
# t= 14.71 hours: min/max  -0.63,   0.43
# t= 14.75 hours: min/max  -0.63,   0.43
# t= 14.79 hours: min/max  -0.63,   0.44
# t= 14.83 hours: min/max  -0.63,   0.44
# t= 14.88 hours: min/max  -0.63,   0.44
# t= 14.92 hours: min/max  -0.63,   0.44
# t= 14.96 hours: min/max  -0.63,   0.45
# t= 15.00 hours: min/max  -0.63,   0.45
# t= 15.04 hours: min/max  -0.63,   0.45
# t= 15.08 hours: min/max  -0.64,   0.46
# t= 15.12 hours: min/max  -0.63,   0.46
# t= 15.17 hours: min/max  -0.64,   0.46
# t= 15.21 hours: min/max  -0.64,   0.47
# t= 15.25 hours: min/max  -0.64,   0.47
# t= 15.29 hours: min/max  -0.64,   0.47
# t= 15.33 hours: min/max  -0.64,   0.47
# t= 15.38 hours: min/max  -0.64,   0.48
# t= 15.42 hours: min/max  -0.64,   0.48
# t= 15.46 hours: min/max  -0.64,   0.48
# t= 15.50 hours: min/max  -0.64,   0.48
# t= 15.54 hours: min/max  -0.64,   0.49
# t= 15.58 hours: min/max  -0.64,   0.49
# t= 15.62 hours: min/max  -0.64,   0.49
# t= 15.67 hours: min/max  -0.64,   0.50
# t= 15.71 hours: min/max  -0.64,   0.50
# t= 15.75 hours: min/max  -0.65,   0.50
# t= 15.79 hours: min/max  -0.65,   0.51
# t= 15.83 hours: min/max  -0.65,   0.51
# t= 15.88 hours: min/max  -0.65,   0.51
# t= 15.92 hours: min/max  -0.65,   0.52
# t= 15.96 hours: min/max  -0.65,   0.52
# t= 16.00 hours: min/max  -0.65,   0.52
# t= 16.04 hours: min/max  -0.65,   0.52
# t= 16.08 hours: min/max  -0.65,   0.53
# t= 16.12 hours: min/max  -0.65,   0.53
# t= 16.17 hours: min/max  -0.65,   0.53
# t= 16.21 hours: min/max  -0.65,   0.53
# t= 16.25 hours: min/max  -0.65,   0.54
# t= 16.29 hours: min/max  -0.65,   0.54
# t= 16.33 hours: min/max  -0.65,   0.54
# t= 16.38 hours: min/max  -0.65,   0.55
# t= 16.42 hours: min/max  -0.65,   0.55
# t= 16.46 hours: min/max  -0.65,   0.55
# t= 16.50 hours: min/max  -0.66,   0.56
# t= 16.54 hours: min/max  -0.66,   0.56
# t= 16.58 hours: min/max  -0.65,   0.56
# t= 16.62 hours: min/max  -0.65,   0.56
# t= 16.67 hours: min/max  -0.66,   0.57
# t= 16.71 hours: min/max  -0.66,   0.57
# t= 16.75 hours: min/max  -0.66,   0.57
# t= 16.79 hours: min/max  -0.66,   0.57
# t= 16.83 hours: min/max  -0.66,   0.58
# t= 16.88 hours: min/max  -0.66,   0.58
# t= 16.92 hours: min/max  -0.66,   0.58
# t= 16.96 hours: min/max  -0.66,   0.59
# t= 17.00 hours: min/max  -0.66,   0.59
# t= 17.04 hours: min/max  -0.66,   0.59
# t= 17.08 hours: min/max  -0.66,   0.59
# t= 17.12 hours: min/max  -0.66,   0.60
# t= 17.17 hours: min/max  -0.66,   0.60
# t= 17.21 hours: min/max  -0.66,   0.60
# t= 17.25 hours: min/max  -0.66,   0.60
# t= 17.29 hours: min/max  -0.66,   0.61
# t= 17.33 hours: min/max  -0.66,   0.61
# t= 17.38 hours: min/max  -0.66,   0.61
# t= 17.42 hours: min/max  -0.66,   0.61
# t= 17.46 hours: min/max  -0.66,   0.62
# t= 17.50 hours: min/max  -0.66,   0.62
# t= 17.54 hours: min/max  -0.66,   0.62
# t= 17.58 hours: min/max  -0.66,   0.62
# t= 17.62 hours: min/max  -0.67,   0.62
# t= 17.67 hours: min/max  -0.66,   0.63
# t= 17.71 hours: min/max  -0.66,   0.63
# t= 17.75 hours: min/max  -0.66,   0.63
# t= 17.79 hours: min/max  -0.67,   0.63
# t= 17.83 hours: min/max  -0.67,   0.64
# t= 17.88 hours: min/max  -0.67,   0.64
# t= 17.92 hours: min/max  -0.67,   0.65
# t= 17.96 hours: min/max  -0.67,   0.65
# t= 18.00 hours: min/max  -0.67,   0.65
# t= 18.04 hours: min/max  -0.67,   0.65
# t= 18.08 hours: min/max  -0.67,   0.65
# t= 18.12 hours: min/max  -0.67,   0.66
# t= 18.17 hours: min/max  -0.67,   0.66
# t= 18.21 hours: min/max  -0.67,   0.65
# t= 18.25 hours: min/max  -0.67,   0.65
# t= 18.29 hours: min/max  -0.67,   0.65
# t= 18.33 hours: min/max  -0.67,   0.66
# t= 18.38 hours: min/max  -0.67,   0.66
# t= 18.42 hours: min/max  -0.67,   0.66
# t= 18.46 hours: min/max  -0.67,   0.66
# t= 18.50 hours: min/max  -0.67,   0.66
# t= 18.54 hours: min/max  -0.68,   0.67
# t= 18.58 hours: min/max  -0.67,   0.67
# t= 18.62 hours: min/max  -0.67,   0.67
# t= 18.67 hours: min/max  -0.68,   0.67
# t= 18.71 hours: min/max  -0.68,   0.67
# t= 18.75 hours: min/max  -0.68,   0.68
# t= 18.79 hours: min/max  -0.68,   0.68
# t= 18.83 hours: min/max  -0.68,   0.68
# t= 18.88 hours: min/max  -0.68,   0.68
# t= 18.92 hours: min/max  -0.68,   0.68
# t= 18.96 hours: min/max  -0.68,   0.68
# t= 19.00 hours: min/max  -0.68,   0.69
# t= 19.04 hours: min/max  -0.68,   0.69
# t= 19.08 hours: min/max  -0.68,   0.69
# t= 19.12 hours: min/max  -0.68,   0.69
# t= 19.17 hours: min/max  -0.68,   0.69
# t= 19.21 hours: min/max  -0.68,   0.69
# t= 19.25 hours: min/max  -0.68,   0.69
# t= 19.29 hours: min/max  -0.68,   0.70
# t= 19.33 hours: min/max  -0.68,   0.70
# t= 19.38 hours: min/max  -0.68,   0.70
# t= 19.42 hours: min/max  -0.69,   0.70
# t= 19.46 hours: min/max  -0.69,   0.70
# t= 19.50 hours: min/max  -0.69,   0.71
# t= 19.54 hours: min/max  -0.69,   0.71
# t= 19.58 hours: min/max  -0.69,   0.71
# t= 19.62 hours: min/max  -0.69,   0.71
# t= 19.67 hours: min/max  -0.69,   0.71
# t= 19.71 hours: min/max  -0.69,   0.72
# t= 19.75 hours: min/max  -0.69,   0.72
# t= 19.79 hours: min/max  -0.69,   0.72
# t= 19.83 hours: min/max  -0.69,   0.72
# t= 19.88 hours: min/max  -0.69,   0.73
# t= 19.92 hours: min/max  -0.69,   0.73
# t= 19.96 hours: min/max  -0.69,   0.73
# t= 20.00 hours: min/max  -0.69,   0.73
# t= 20.04 hours: min/max  -0.69,   0.74
# t= 20.08 hours: min/max  -0.69,   0.74
# t= 20.12 hours: min/max  -0.69,   0.74
# t= 20.17 hours: min/max  -0.70,   0.74
# t= 20.21 hours: min/max  -0.70,   0.75
# t= 20.25 hours: min/max  -0.69,   0.75
# t= 20.29 hours: min/max  -0.69,   0.75
# t= 20.33 hours: min/max  -0.70,   0.76
# t= 20.38 hours: min/max  -0.70,   0.76
# t= 20.42 hours: min/max  -0.70,   0.76
# t= 20.46 hours: min/max  -0.70,   0.76
# t= 20.50 hours: min/max  -0.70,   0.77
# t= 20.54 hours: min/max  -0.70,   0.77
# t= 20.58 hours: min/max  -0.70,   0.77
# t= 20.62 hours: min/max  -0.70,   0.78
# t= 20.67 hours: min/max  -0.70,   0.78
# t= 20.71 hours: min/max  -0.70,   0.78
# t= 20.75 hours: min/max  -0.70,   0.79
# t= 20.79 hours: min/max  -0.70,   0.79
# t= 20.83 hours: min/max  -0.70,   0.79
# t= 20.88 hours: min/max  -0.70,   0.79
# t= 20.92 hours: min/max  -0.70,   0.80
# t= 20.96 hours: min/max  -0.70,   0.80
# t= 21.00 hours: min/max  -0.70,   0.80
# t= 21.04 hours: min/max  -0.70,   0.81
# t= 21.08 hours: min/max  -0.70,   0.81
# t= 21.12 hours: min/max  -0.70,   0.81
# t= 21.17 hours: min/max  -0.70,   0.82
# t= 21.21 hours: min/max  -0.70,   0.82
# t= 21.25 hours: min/max  -0.70,   0.82
# t= 21.29 hours: min/max  -0.70,   0.82
# t= 21.33 hours: min/max  -0.70,   0.83
# t= 21.38 hours: min/max  -0.70,   0.83
# t= 21.42 hours: min/max  -0.70,   0.83
# t= 21.46 hours: min/max  -0.71,   0.83
# t= 21.50 hours: min/max  -0.71,   0.83
# t= 21.54 hours: min/max  -0.71,   0.84
# t= 21.58 hours: min/max  -0.71,   0.84
# t= 21.62 hours: min/max  -0.71,   0.84
# t= 21.67 hours: min/max  -0.71,   0.84
# t= 21.71 hours: min/max  -0.71,   0.85
# t= 21.75 hours: min/max  -0.71,   0.85
# t= 21.79 hours: min/max  -0.71,   0.85
# t= 21.83 hours: min/max  -0.71,   0.85
# t= 21.88 hours: min/max  -0.71,   0.86
# t= 21.92 hours: min/max  -0.71,   0.86
# t= 21.96 hours: min/max  -0.71,   0.86
# t= 22.00 hours: min/max  -0.71,   0.86
# t= 22.04 hours: min/max  -0.71,   0.86
# t= 22.08 hours: min/max  -0.71,   0.87
# t= 22.12 hours: min/max  -0.71,   0.87
# t= 22.17 hours: min/max  -0.72,   0.87
# t= 22.21 hours: min/max  -0.72,   0.87
# t= 22.25 hours: min/max  -0.72,   0.87
# t= 22.29 hours: min/max  -0.72,   0.87
# t= 22.33 hours: min/max  -0.72,   0.88
# t= 22.38 hours: min/max  -0.72,   0.88
# t= 22.42 hours: min/max  -0.72,   0.88
# t= 22.46 hours: min/max  -0.72,   0.88
# t= 22.50 hours: min/max  -0.72,   0.89
# t= 22.54 hours: min/max  -0.72,   0.89
# t= 22.58 hours: min/max  -0.72,   0.89
# t= 22.62 hours: min/max  -0.72,   0.89
# t= 22.67 hours: min/max  -0.72,   0.89
# t= 22.71 hours: min/max  -0.73,   0.89
# t= 22.75 hours: min/max  -0.73,   0.90
# t= 22.79 hours: min/max  -0.73,   0.90
# t= 22.83 hours: min/max  -0.73,   0.90
# t= 22.88 hours: min/max  -0.73,   0.90
# t= 22.92 hours: min/max  -0.73,   0.90
# t= 22.96 hours: min/max  -0.73,   0.90
# t= 23.00 hours: min/max  -0.73,   0.90
# t= 23.04 hours: min/max  -0.73,   0.90
# t= 23.08 hours: min/max  -0.74,   0.91
# t= 23.12 hours: min/max  -0.74,   0.91
# t= 23.17 hours: min/max  -0.74,   0.91
# t= 23.21 hours: min/max  -0.74,   0.91
# t= 23.25 hours: min/max  -0.74,   0.91
# t= 23.29 hours: min/max  -0.75,   0.92
# t= 23.33 hours: min/max  -0.75,   0.92
# t= 23.38 hours: min/max  -0.75,   0.92
# t= 23.42 hours: min/max  -0.75,   0.92
# t= 23.46 hours: min/max  -0.75,   0.92
# t= 23.50 hours: min/max  -0.75,   0.92
# t= 23.54 hours: min/max  -0.75,   0.93
# t= 23.58 hours: min/max  -0.75,   0.93
# t= 23.62 hours: min/max  -0.75,   0.93
# t= 23.67 hours: min/max  -0.75,   0.93
# t= 23.71 hours: min/max  -0.75,   0.93
# t= 23.75 hours: min/max  -0.75,   0.93
# t= 23.79 hours: min/max  -0.75,   0.94
# t= 23.83 hours: min/max  -0.75,   0.94
# t= 23.88 hours: min/max  -0.75,   0.94
# t= 23.92 hours: min/max  -0.75,   0.94
# t= 23.96 hours: min/max  -0.75,   0.94
# t= 24.00 hours: min/max  -0.75,   0.95
# t= 24.04 hours: min/max  -0.75,   0.95
# t= 24.08 hours: min/max  -0.75,   0.95
# t= 24.12 hours: min/max  -0.75,   0.95
# t= 24.17 hours: min/max  -0.75,   0.96
# t= 24.21 hours: min/max  -0.76,   0.96
# t= 24.25 hours: min/max  -0.76,   0.96
# t= 24.29 hours: min/max  -0.76,   0.96
# t= 24.33 hours: min/max  -0.76,   0.97
# t= 24.38 hours: min/max  -0.77,   0.97
# t= 24.42 hours: min/max  -0.77,   0.97
# t= 24.46 hours: min/max  -0.77,   0.97
# t= 24.50 hours: min/max  -0.77,   0.97
# t= 24.54 hours: min/max  -0.77,   0.97
# t= 24.58 hours: min/max  -0.77,   0.97
# t= 24.62 hours: min/max  -0.77,   0.98
# t= 24.67 hours: min/max  -0.77,   0.98
# t= 24.71 hours: min/max  -0.78,   0.98
# t= 24.75 hours: min/max  -0.78,   0.98
# t= 24.79 hours: min/max  -0.78,   0.98
# t= 24.83 hours: min/max  -0.78,   0.98
# t= 24.88 hours: min/max  -0.78,   0.98
# t= 24.92 hours: min/max  -0.78,   0.98
# t= 24.96 hours: min/max  -0.78,   0.97
# t= 25.00 hours: min/max  -0.77,   0.97
# t= 25.04 hours: min/max  -0.78,   0.97
# t= 25.08 hours: min/max  -0.78,   0.97
# t= 25.12 hours: min/max  -0.78,   0.97
# t= 25.17 hours: min/max  -0.78,   0.97
# t= 25.21 hours: min/max  -0.78,   0.97
# t= 25.25 hours: min/max  -0.78,   0.97
# t= 25.29 hours: min/max  -0.78,   0.97
# t= 25.33 hours: min/max  -0.78,   0.97
# t= 25.38 hours: min/max  -0.78,   0.97
# t= 25.42 hours: min/max  -0.78,   0.97
# t= 25.46 hours: min/max  -0.78,   0.98
# t= 25.50 hours: min/max  -0.78,   0.98
# t= 25.54 hours: min/max  -0.78,   0.98
# t= 25.58 hours: min/max  -0.78,   0.99
# t= 25.62 hours: min/max  -0.78,   1.00
# t= 25.67 hours: min/max  -0.78,   1.01
# t= 25.71 hours: min/max  -0.78,   1.02
# t= 25.75 hours: min/max  -0.78,   1.03
# t= 25.79 hours: min/max  -0.79,   1.04
# t= 25.83 hours: min/max  -0.79,   1.05
# t= 25.88 hours: min/max  -0.79,   1.06
# t= 25.92 hours: min/max  -0.79,   1.07
# t= 25.96 hours: min/max  -0.79,   1.08
# t= 26.00 hours: min/max  -0.79,   1.08
# t= 26.04 hours: min/max  -0.79,   1.10
# t= 26.08 hours: min/max  -0.79,   1.11
# t= 26.12 hours: min/max  -0.79,   1.11
# t= 26.17 hours: min/max  -0.79,   1.10
# t= 26.21 hours: min/max  -0.79,   1.11
# t= 26.25 hours: min/max  -0.79,   1.11
# t= 26.29 hours: min/max  -0.79,   1.10
# t= 26.33 hours: min/max  -0.79,   1.10
# t= 26.38 hours: min/max  -0.79,   1.11
# t= 26.42 hours: min/max  -0.79,   1.10
# t= 26.46 hours: min/max  -0.79,   1.09
# t= 26.50 hours: min/max  -0.79,   1.09
# t= 26.54 hours: min/max  -0.79,   1.09
# t= 26.58 hours: min/max  -0.79,   1.09
# t= 26.62 hours: min/max  -0.79,   1.09
# t= 26.67 hours: min/max  -0.79,   1.09
# t= 26.71 hours: min/max  -0.79,   1.09
# t= 26.75 hours: min/max  -0.79,   1.09
# t= 26.79 hours: min/max  -0.79,   1.09
# t= 26.83 hours: min/max  -0.79,   1.10
# t= 26.88 hours: min/max  -0.79,   1.10
# t= 26.92 hours: min/max  -0.79,   1.10
# t= 26.96 hours: min/max  -0.79,   1.11
# t= 27.00 hours: min/max  -0.79,   1.11
# t= 27.04 hours: min/max  -0.79,   1.12
# t= 27.08 hours: min/max  -0.79,   1.13
# t= 27.12 hours: min/max  -0.80,   1.13
# t= 27.17 hours: min/max  -0.80,   1.13
# t= 27.21 hours: min/max  -0.80,   1.14
# t= 27.25 hours: min/max  -0.80,   1.15
# t= 27.29 hours: min/max  -0.80,   1.15
# t= 27.33 hours: min/max  -0.80,   1.15
# t= 27.38 hours: min/max  -0.81,   1.16
# t= 27.42 hours: min/max  -0.81,   1.16
# t= 27.46 hours: min/max  -0.81,   1.17
# t= 27.50 hours: min/max  -0.81,   1.17
# t= 27.54 hours: min/max  -0.82,   1.17
# t= 27.58 hours: min/max  -0.82,   1.18
# t= 27.62 hours: min/max  -0.82,   1.18
# t= 27.67 hours: min/max  -0.83,   1.18
# t= 27.71 hours: min/max  -0.83,   1.18
# t= 27.75 hours: min/max  -0.83,   1.19
# t= 27.79 hours: min/max  -0.83,   1.19
# t= 27.83 hours: min/max  -0.83,   1.20
# t= 27.88 hours: min/max  -0.83,   1.20
# t= 27.92 hours: min/max  -0.83,   1.20
# t= 27.96 hours: min/max  -0.83,   1.21
# t= 28.00 hours: min/max  -0.84,   1.21
# t= 28.04 hours: min/max  -0.84,   1.21
# t= 28.08 hours: min/max  -0.83,   1.22
# t= 28.12 hours: min/max  -0.83,   1.22
# t= 28.17 hours: min/max  -0.83,   1.23
# t= 28.21 hours: min/max  -0.83,   1.23
# t= 28.25 hours: min/max  -0.82,   1.23
# t= 28.29 hours: min/max  -0.82,   1.24
# t= 28.33 hours: min/max  -0.82,   1.24
# t= 28.38 hours: min/max  -0.81,   1.25
# t= 28.42 hours: min/max  -0.81,   1.25
# t= 28.46 hours: min/max  -0.80,   1.26
# t= 28.50 hours: min/max  -0.80,   1.26
# t= 28.54 hours: min/max  -0.79,   1.27
# t= 28.58 hours: min/max  -0.79,   1.27
# t= 28.62 hours: min/max  -0.80,   1.28
# t= 28.67 hours: min/max  -0.79,   1.28
# t= 28.71 hours: min/max  -0.78,   1.29
# t= 28.75 hours: min/max  -0.78,   1.30
# t= 28.79 hours: min/max  -0.79,   1.30
# t= 28.83 hours: min/max  -0.79,   1.30
# t= 28.88 hours: min/max  -0.79,   1.31
# t= 28.92 hours: min/max  -0.80,   1.32
# t= 28.96 hours: min/max  -0.81,   1.32
# t= 29.00 hours: min/max  -0.81,   1.32
# t= 29.04 hours: min/max  -0.82,   1.33
# t= 29.08 hours: min/max  -0.82,   1.33
# t= 29.12 hours: min/max  -0.83,   1.33
# t= 29.17 hours: min/max  -0.83,   1.33
# t= 29.21 hours: min/max  -0.83,   1.33
# t= 29.25 hours: min/max  -0.84,   1.33
# t= 29.29 hours: min/max  -0.84,   1.33
# t= 29.33 hours: min/max  -0.84,   1.33
# t= 29.38 hours: min/max  -0.84,   1.33
# t= 29.42 hours: min/max  -0.84,   1.33
# t= 29.46 hours: min/max  -0.84,   1.32
# t= 29.50 hours: min/max  -0.84,   1.33
# t= 29.54 hours: min/max  -0.84,   1.32
# t= 29.58 hours: min/max  -0.83,   1.31
# t= 29.62 hours: min/max  -0.83,   1.30
# t= 29.67 hours: min/max  -0.83,   1.31
# t= 29.71 hours: min/max  -0.83,   1.30
# t= 29.75 hours: min/max  -0.82,   1.29
# t= 29.79 hours: min/max  -0.82,   1.29
# t= 29.83 hours: min/max  -0.82,   1.29
# t= 29.88 hours: min/max  -0.81,   1.29
# t= 29.92 hours: min/max  -0.81,   1.28
# t= 29.96 hours: min/max  -0.81,   1.28
# t= 30.00 hours: min/max  -0.81,   1.29
# t= 30.04 hours: min/max  -0.81,   1.29
# t= 30.08 hours: min/max  -0.81,   1.29
# t= 30.12 hours: min/max  -0.81,   1.30
# t= 30.17 hours: min/max  -0.81,   1.31
# t= 30.21 hours: min/max  -0.82,   1.31
# t= 30.25 hours: min/max  -0.82,   1.32
# t= 30.29 hours: min/max  -0.82,   1.32
# t= 30.33 hours: min/max  -0.82,   1.33
# t= 30.38 hours: min/max  -0.82,   1.33
# t= 30.42 hours: min/max  -0.83,   1.33
# t= 30.46 hours: min/max  -0.82,   1.33
# t= 30.50 hours: min/max  -0.82,   1.33
# t= 30.54 hours: min/max  -0.82,   1.34
# t= 30.58 hours: min/max  -0.83,   1.34
# t= 30.62 hours: min/max  -0.83,   1.33
# t= 30.67 hours: min/max  -0.82,   1.33
# t= 30.71 hours: min/max  -0.82,   1.33
# t= 30.75 hours: min/max  -0.82,   1.33
# t= 30.79 hours: min/max  -0.82,   1.33
# t= 30.83 hours: min/max  -0.82,   1.33
# t= 30.88 hours: min/max  -0.82,   1.33
# t= 30.92 hours: min/max  -0.81,   1.34
# t= 30.96 hours: min/max  -0.81,   1.34
# t= 31.00 hours: min/max  -0.81,   1.35
# t= 31.04 hours: min/max  -0.80,   1.36
# t= 31.08 hours: min/max  -0.80,   1.37
# t= 31.12 hours: min/max  -0.80,   1.39
# t= 31.17 hours: min/max  -0.80,   1.40
# t= 31.21 hours: min/max  -0.81,   1.41
# t= 31.25 hours: min/max  -0.82,   1.43
# t= 31.29 hours: min/max  -0.82,   1.45
# t= 31.33 hours: min/max  -0.82,   1.46
# t= 31.38 hours: min/max  -0.83,   1.48
# t= 31.42 hours: min/max  -0.84,   1.49
# t= 31.46 hours: min/max  -0.85,   1.51
# t= 31.50 hours: min/max  -0.85,   1.53
# t= 31.54 hours: min/max  -0.86,   1.55
# t= 31.58 hours: min/max  -0.86,   1.56
# t= 31.62 hours: min/max  -0.86,   1.57
# t= 31.67 hours: min/max  -0.87,   1.59
# t= 31.71 hours: min/max  -0.87,   1.60
# t= 31.75 hours: min/max  -0.87,   1.61
# t= 31.79 hours: min/max  -0.87,   1.62
# t= 31.83 hours: min/max  -0.88,   1.63
# t= 31.88 hours: min/max  -0.88,   1.65
# t= 31.92 hours: min/max  -0.88,   1.65
# t= 31.96 hours: min/max  -0.89,   1.66
# t= 32.00 hours: min/max  -0.90,   1.67
# t= 32.04 hours: min/max  -0.90,   1.68
# t= 32.08 hours: min/max  -0.90,   1.68
# t= 32.12 hours: min/max  -0.93,   1.68
# t= 32.17 hours: min/max  -0.94,   1.69
# t= 32.21 hours: min/max  -0.96,   1.70
# t= 32.25 hours: min/max  -0.95,   1.70
# t= 32.29 hours: min/max  -0.96,   1.70
# t= 32.33 hours: min/max  -0.99,   1.71
# t= 32.38 hours: min/max  -0.99,   1.71
# t= 32.42 hours: min/max  -0.97,   1.71
# t= 32.46 hours: min/max  -1.00,   1.72
# t= 32.50 hours: min/max  -1.01,   1.72
# t= 32.54 hours: min/max  -1.01,   1.72
# t= 32.58 hours: min/max  -1.02,   1.72
# t= 32.62 hours: min/max  -1.03,   1.73
# t= 32.67 hours: min/max  -1.03,   1.73
# t= 32.71 hours: min/max  -1.03,   1.72
# t= 32.75 hours: min/max  -1.04,   1.72
# t= 32.79 hours: min/max  -1.04,   1.74
# t= 32.83 hours: min/max  -1.04,   1.74
# t= 32.88 hours: min/max  -1.04,   1.74
# t= 32.92 hours: min/max  -1.04,   1.72
# t= 32.96 hours: min/max  -1.04,   1.74
# t= 33.00 hours: min/max  -1.04,   1.74
# t= 33.04 hours: min/max  -1.05,   1.74
# t= 33.08 hours: min/max  -1.04,   1.72
# t= 33.12 hours: min/max  -1.02,   1.73
# t= 33.17 hours: min/max  -1.04,   1.74
# t= 33.21 hours: min/max  -1.04,   1.75
# t= 33.25 hours: min/max  -1.04,   1.73
# t= 33.29 hours: min/max  -1.03,   1.72
# t= 33.33 hours: min/max  -1.03,   1.74
# t= 33.38 hours: min/max  -1.05,   1.75
# t= 33.42 hours: min/max  -1.07,   1.74
# t= 33.46 hours: min/max  -1.07,   1.72
# t= 33.50 hours: min/max  -1.06,   1.73
# t= 33.54 hours: min/max  -1.07,   1.74
# t= 33.58 hours: min/max  -1.09,   1.74
# t= 33.62 hours: min/max  -1.10,   1.72
# t= 33.67 hours: min/max  -1.09,   1.72
# t= 33.71 hours: min/max  -1.09,   1.74
# t= 33.75 hours: min/max  -1.11,   1.74
# t= 33.79 hours: min/max  -1.12,   1.73
# t= 33.83 hours: min/max  -1.12,   1.71
# t= 33.88 hours: min/max  -1.11,   1.73
# t= 33.92 hours: min/max  -1.13,   1.74
# t= 33.96 hours: min/max  -1.14,   1.73
# t= 34.00 hours: min/max  -1.15,   1.71
# t= 34.04 hours: min/max  -1.13,   1.72
# t= 34.08 hours: min/max  -1.14,   1.74
# t= 34.12 hours: min/max  -1.15,   1.73
# t= 34.17 hours: min/max  -1.17,   1.72
# t= 34.21 hours: min/max  -1.16,   1.71
# t= 34.25 hours: min/max  -1.15,   1.73
# t= 34.29 hours: min/max  -1.17,   1.73
# t= 34.33 hours: min/max  -1.19,   1.72
# t= 34.38 hours: min/max  -1.18,   1.71
# t= 34.42 hours: min/max  -1.17,   1.72
# t= 34.46 hours: min/max  -1.18,   1.73
# t= 34.50 hours: min/max  -1.20,   1.73
# t= 34.54 hours: min/max  -1.20,   1.71
# t= 34.58 hours: min/max  -1.19,   1.72
# t= 34.62 hours: min/max  -1.18,   1.73
# t= 34.67 hours: min/max  -1.21,   1.73
# t= 34.71 hours: min/max  -1.22,   1.72
# t= 34.75 hours: min/max  -1.21,   1.72
# t= 34.79 hours: min/max  -1.20,   1.72
# t= 34.83 hours: min/max  -1.21,   1.74
# t= 34.88 hours: min/max  -1.23,   1.73
# t= 34.92 hours: min/max  -1.23,   1.72
# t= 34.96 hours: min/max  -1.22,   1.72
# t= 35.00 hours: min/max  -1.22,   1.74
# t= 35.04 hours: min/max  -1.24,   1.74
# t= 35.08 hours: min/max  -1.25,   1.73
# t= 35.12 hours: min/max  -1.24,   1.73
# t= 35.17 hours: min/max  -1.23,   1.74
# t= 35.21 hours: min/max  -1.25,   1.74
# t= 35.25 hours: min/max  -1.26,   1.74
# t= 35.29 hours: min/max  -1.26,   1.74
# t= 35.33 hours: min/max  -1.24,   1.74
# t= 35.38 hours: min/max  -1.26,   1.75
# t= 35.42 hours: min/max  -1.27,   1.75
# t= 35.46 hours: min/max  -1.27,   1.74
# t= 35.50 hours: min/max  -1.26,   1.75
# t= 35.54 hours: min/max  -1.26,   1.76
# t= 35.58 hours: min/max  -1.28,   1.77
# t= 35.62 hours: min/max  -1.29,   1.76
# t= 35.67 hours: min/max  -1.27,   1.76
# t= 35.71 hours: min/max  -1.26,   1.76
# t= 35.75 hours: min/max  -1.29,   1.78
# t= 35.79 hours: min/max  -1.30,   1.78
# t= 35.83 hours: min/max  -1.29,   1.77
# t= 35.88 hours: min/max  -1.28,   1.78
# t= 35.92 hours: min/max  -1.29,   1.79
# t= 35.96 hours: min/max  -1.31,   1.80
# t= 36.00 hours: min/max  -1.31,   1.78
# t= 36.04 hours: min/max  -1.30,   1.79
# t= 36.08 hours: min/max  -1.30,   1.80
# t= 36.12 hours: min/max  -1.32,   1.81
# t= 36.17 hours: min/max  -1.33,   1.81
# t= 36.21 hours: min/max  -1.32,   1.80
# t= 36.25 hours: min/max  -1.30,   1.81
# t= 36.29 hours: min/max  -1.32,   1.83
# t= 36.33 hours: min/max  -1.34,   1.83
# t= 36.38 hours: min/max  -1.34,   1.82
# t= 36.42 hours: min/max  -1.32,   1.83
# t= 36.46 hours: min/max  -1.33,   1.84
# t= 36.50 hours: min/max  -1.35,   1.85
# t= 36.54 hours: min/max  -1.35,   1.85
# t= 36.58 hours: min/max  -1.35,   1.85
# t= 36.62 hours: min/max  -1.33,   1.86
# t= 36.67 hours: min/max  -1.36,   1.87
# t= 36.71 hours: min/max  -1.36,   1.88
# t= 36.75 hours: min/max  -1.37,   1.87
# t= 36.79 hours: min/max  -1.35,   1.88
# t= 36.83 hours: min/max  -1.36,   1.89
# t= 36.88 hours: min/max  -1.38,   1.90
# t= 36.92 hours: min/max  -1.39,   1.89
# t= 36.96 hours: min/max  -1.37,   1.90
# t= 37.00 hours: min/max  -1.37,   1.91
# t= 37.04 hours: min/max  -1.39,   1.93
# t= 37.08 hours: min/max  -1.40,   1.92
# t= 37.12 hours: min/max  -1.39,   1.92
# t= 37.17 hours: min/max  -1.37,   1.92
# t= 37.21 hours: min/max  -1.40,   1.95
# t= 37.25 hours: min/max  -1.42,   1.95
# t= 37.29 hours: min/max  -1.41,   1.95
# t= 37.33 hours: min/max  -1.40,   1.94
# t= 37.38 hours: min/max  -1.40,   1.97
# t= 37.42 hours: min/max  -1.43,   1.98
# t= 37.46 hours: min/max  -1.44,   1.98
# t= 37.50 hours: min/max  -1.43,   1.96
# t= 37.54 hours: min/max  -1.41,   1.99
# t= 37.58 hours: min/max  -1.44,   2.01
# t= 37.62 hours: min/max  -1.46,   2.01
# t= 37.67 hours: min/max  -1.45,   2.00
# t= 37.71 hours: min/max  -1.43,   2.00
# t= 37.75 hours: min/max  -1.45,   2.03
# t= 37.79 hours: min/max  -1.47,   2.04
# t= 37.83 hours: min/max  -1.48,   2.04
# t= 37.88 hours: min/max  -1.46,   2.03
# t= 37.92 hours: min/max  -1.46,   2.06
# t= 37.96 hours: min/max  -1.49,   2.07
# t= 38.00 hours: min/max  -1.50,   2.08
# t= 38.04 hours: min/max  -1.49,   2.06
# t= 38.08 hours: min/max  -1.47,   2.08
# t= 38.12 hours: min/max  -1.50,   2.10
# t= 38.17 hours: min/max  -1.51,   2.11
# t= 38.21 hours: min/max  -1.52,   2.10
# t= 38.25 hours: min/max  -1.50,   2.11
# t= 38.29 hours: min/max  -1.51,   2.13
# t= 38.33 hours: min/max  -1.53,   2.15
# t= 38.38 hours: min/max  -1.54,   2.14
# t= 38.42 hours: min/max  -1.53,   2.14
# t= 38.46 hours: min/max  -1.52,   2.17
# t= 38.50 hours: min/max  -1.54,   2.19
# t= 38.54 hours: min/max  -1.57,   2.19
# t= 38.58 hours: min/max  -1.56,   2.18
# t= 38.62 hours: min/max  -1.55,   2.20
# t= 38.67 hours: min/max  -1.56,   2.23
# t= 38.71 hours: min/max  -1.59,   2.24
# t= 38.75 hours: min/max  -1.59,   2.23
# t= 38.79 hours: min/max  -1.58,   2.24
# t= 38.83 hours: min/max  -1.57,   2.27
# t= 38.88 hours: min/max  -1.61,   2.29
# t= 38.92 hours: min/max  -1.62,   2.29
# t= 38.96 hours: min/max  -1.62,   2.28
# t= 39.00 hours: min/max  -1.59,   2.31
# t= 39.04 hours: min/max  -1.62,   2.34
# t= 39.08 hours: min/max  -1.64,   2.34
# t= 39.12 hours: min/max  -1.65,   2.33
# t= 39.17 hours: min/max  -1.63,   2.35
# t= 39.21 hours: min/max  -1.64,   2.39
# t= 39.25 hours: min/max  -1.67,   2.39
# t= 39.29 hours: min/max  -1.68,   2.39
# t= 39.33 hours: min/max  -1.67,   2.38
# t= 39.38 hours: min/max  -1.66,   2.42
# t= 39.42 hours: min/max  -1.69,   2.43
# t= 39.46 hours: min/max  -1.71,   2.44
# t= 39.50 hours: min/max  -1.71,   2.41
# t= 39.54 hours: min/max  -1.69,   2.43
# t= 39.58 hours: min/max  -1.70,   2.45
# t= 39.62 hours: min/max  -1.73,   2.46
# t= 39.67 hours: min/max  -1.74,   2.44
# t= 39.71 hours: min/max  -1.73,   2.42
# t= 39.75 hours: min/max  -1.72,   2.44
# t= 39.79 hours: min/max  -1.75,   2.46
# t= 39.83 hours: min/max  -1.77,   2.45
# t= 39.88 hours: min/max  -1.76,   2.42
# t= 39.92 hours: min/max  -1.74,   2.41
# t= 39.96 hours: min/max  -1.76,   2.43
# t= 40.00 hours: min/max  -1.79,   2.43
# t= 40.04 hours: min/max  -1.79,   2.41
# t= 40.08 hours: min/max  -1.78,   2.37
# t= 40.12 hours: min/max  -1.77,   2.40
# t= 40.17 hours: min/max  -1.81,   2.40
# t= 40.21 hours: min/max  -1.82,   2.39
# t= 40.25 hours: min/max  -1.82,   2.35
# t= 40.29 hours: min/max  -1.79,   2.37
# t= 40.33 hours: min/max  -1.82,   2.38
# t= 40.38 hours: min/max  -1.84,   2.38
# t= 40.42 hours: min/max  -1.85,   2.35
# t= 40.46 hours: min/max  -1.82,   2.36
# t= 40.50 hours: min/max  -1.83,   2.38
# t= 40.54 hours: min/max  -1.85,   2.39
# t= 40.58 hours: min/max  -1.87,   2.37
# t= 40.62 hours: min/max  -1.85,   2.36
# t= 40.67 hours: min/max  -1.83,   2.40
# t= 40.71 hours: min/max  -1.86,   2.41
# t= 40.75 hours: min/max  -1.89,   2.40
# t= 40.79 hours: min/max  -1.87,   2.37
# t= 40.83 hours: min/max  -1.86,   2.42
# t= 40.88 hours: min/max  -1.86,   2.43
# t= 40.92 hours: min/max  -1.90,   2.44
# t= 40.96 hours: min/max  -1.90,   2.41
# t= 41.00 hours: min/max  -1.89,   2.43
# t= 41.04 hours: min/max  -1.87,   2.45
# t= 41.08 hours: min/max  -1.91,   2.47
# t= 41.12 hours: min/max  -1.93,   2.45
# t= 41.17 hours: min/max  -1.92,   2.44
# t= 41.21 hours: min/max  -1.90,   2.47
# t= 41.25 hours: min/max  -1.94,   2.49
# t= 41.29 hours: min/max  -1.97,   2.48
# t= 41.33 hours: min/max  -1.97,   2.46
# t= 41.38 hours: min/max  -1.95,   2.48
# t= 41.42 hours: min/max  -1.99,   2.51
# t= 41.46 hours: min/max  -2.03,   2.50
# t= 41.50 hours: min/max  -2.03,   2.49
# t= 41.54 hours: min/max  -2.03,   2.48
# t= 41.58 hours: min/max  -2.05,   2.52
# t= 41.62 hours: min/max  -2.11,   2.53
# t= 41.67 hours: min/max  -2.12,   2.52
# t= 41.71 hours: min/max  -2.12,   2.49
# t= 41.75 hours: min/max  -2.12,   2.53
# t= 41.79 hours: min/max  -2.17,   2.55
# t= 41.83 hours: min/max  -2.20,   2.55
# t= 41.88 hours: min/max  -2.22,   2.52
# t= 41.92 hours: min/max  -2.20,   2.53
# t= 41.96 hours: min/max  -2.23,   2.56
# t= 42.00 hours: min/max  -2.27,   2.57
# t= 42.04 hours: min/max  -2.29,   2.55
# t= 42.08 hours: min/max  -2.28,   2.54
# t= 42.12 hours: min/max  -2.27,   2.58
# t= 42.17 hours: min/max  -2.31,   2.59
# t= 42.21 hours: min/max  -2.35,   2.58
# t= 42.25 hours: min/max  -2.34,   2.55
# t= 42.29 hours: min/max  -2.33,   2.59
# t= 42.33 hours: min/max  -2.34,   2.61
# t= 42.38 hours: min/max  -2.39,   2.62
# t= 42.42 hours: min/max  -2.39,   2.59
# t= 42.46 hours: min/max  -2.39,   2.60
# t= 42.50 hours: min/max  -2.36,   2.62
# t= 42.54 hours: min/max  -2.41,   2.65
# t= 42.58 hours: min/max  -2.43,   2.63
# t= 42.62 hours: min/max  -2.43,   2.60
# t= 42.67 hours: min/max  -2.40,   2.64
# t= 42.71 hours: min/max  -2.43,   2.67
# t= 42.75 hours: min/max  -2.46,   2.66
# t= 42.79 hours: min/max  -2.47,   2.64
# t= 42.83 hours: min/max  -2.45,   2.65
# t= 42.88 hours: min/max  -2.44,   2.69
# t= 42.92 hours: min/max  -2.49,   2.69
# t= 42.96 hours: min/max  -2.51,   2.68
# t= 43.00 hours: min/max  -2.49,   2.66
# t= 43.04 hours: min/max  -2.46,   2.71
# t= 43.08 hours: min/max  -2.50,   2.72
# t= 43.12 hours: min/max  -2.53,   2.72
# t= 43.17 hours: min/max  -2.54,   2.68
# t= 43.21 hours: min/max  -2.51,   2.72
# t= 43.25 hours: min/max  -2.52,   2.75
# t= 43.29 hours: min/max  -2.55,   2.75
# t= 43.33 hours: min/max  -2.57,   2.72
# t= 43.38 hours: min/max  -2.56,   2.73
# t= 43.42 hours: min/max  -2.53,   2.77
# t= 43.46 hours: min/max  -2.57,   2.78
# t= 43.50 hours: min/max  -2.60,   2.76
# t= 43.54 hours: min/max  -2.59,   2.74
# t= 43.58 hours: min/max  -2.57,   2.78
# t= 43.62 hours: min/max  -2.58,   2.81
# t= 43.67 hours: min/max  -2.63,   2.80
# t= 43.71 hours: min/max  -2.63,   2.78
# t= 43.75 hours: min/max  -2.61,   2.80
# t= 43.79 hours: min/max  -2.59,   2.82
# t= 43.83 hours: min/max  -2.64,   2.84
# t= 43.88 hours: min/max  -2.65,   2.82
# t= 43.92 hours: min/max  -2.65,   2.80
# t= 43.96 hours: min/max  -2.61,   2.84
# t= 44.00 hours: min/max  -2.65,   2.87
# t= 44.04 hours: min/max  -2.67,   2.85
# t= 44.08 hours: min/max  -2.68,   2.82
# t= 44.12 hours: min/max  -2.64,   2.85
# t= 44.17 hours: min/max  -2.65,   2.89
# t= 44.21 hours: min/max  -2.69,   2.89
# t= 44.25 hours: min/max  -2.71,   2.86
# t= 44.29 hours: min/max  -2.68,   2.86
# t= 44.33 hours: min/max  -2.66,   2.91
# t= 44.38 hours: min/max  -2.70,   2.91
# t= 44.42 hours: min/max  -2.73,   2.90
# t= 44.46 hours: min/max  -2.72,   2.86
# t= 44.50 hours: min/max  -2.69,   2.92
# t= 44.54 hours: min/max  -2.71,   2.93
# t= 44.58 hours: min/max  -2.75,   2.94
# t= 44.62 hours: min/max  -2.75,   2.90
# t= 44.67 hours: min/max  -2.73,   2.92
# t= 44.71 hours: min/max  -2.71,   2.95
# t= 44.75 hours: min/max  -2.76,   2.97
# t= 44.79 hours: min/max  -2.79,   2.94
# t= 44.83 hours: min/max  -2.77,   2.93
# t= 44.88 hours: min/max  -2.73,   2.97
# t= 44.92 hours: min/max  -2.77,   3.00
# t= 44.96 hours: min/max  -2.81,   2.97
# t= 45.00 hours: min/max  -2.81,   2.95
# t= 45.04 hours: min/max  -2.78,   2.98
# t= 45.08 hours: min/max  -2.78,   3.01
# t= 45.12 hours: min/max  -2.83,   3.01
# t= 45.17 hours: min/max  -2.84,   2.99
# t= 45.21 hours: min/max  -2.83,   2.98
# t= 45.25 hours: min/max  -2.80,   3.03
# t= 45.29 hours: min/max  -2.85,   3.04
# t= 45.33 hours: min/max  -2.87,   3.03
# t= 45.38 hours: min/max  -2.87,   2.99
# t= 45.42 hours: min/max  -2.83,   3.03
# t= 45.46 hours: min/max  -2.86,   3.06
# t= 45.50 hours: min/max  -2.89,   3.06
# t= 45.54 hours: min/max  -2.92,   3.03
# t= 45.58 hours: min/max  -2.88,   3.04
# t= 45.62 hours: min/max  -2.87,   3.08
# t= 45.67 hours: min/max  -2.92,   3.09
# t= 45.71 hours: min/max  -2.96,   3.07
# t= 45.75 hours: min/max  -2.93,   3.04
# t= 45.79 hours: min/max  -2.91,   3.10
# t= 45.83 hours: min/max  -2.95,   3.11
# t= 45.88 hours: min/max  -2.99,   3.10
# t= 45.92 hours: min/max  -2.99,   3.06
# t= 45.96 hours: min/max  -2.97,   3.10
# t= 46.00 hours: min/max  -2.97,   3.12
# t= 46.04 hours: min/max  -3.02,   3.14
# t= 46.08 hours: min/max  -3.04,   3.10
# t= 46.12 hours: min/max  -3.03,   3.10
# t= 46.17 hours: min/max  -2.99,   3.14
# t= 46.21 hours: min/max  -3.05,   3.16
# t= 46.25 hours: min/max  -3.09,   3.14
# t= 46.29 hours: min/max  -3.09,   3.10
# t= 46.33 hours: min/max  -3.04,   3.15
# t= 46.38 hours: min/max  -3.07,   3.19
# t= 46.42 hours: min/max  -3.13,   3.17
# t= 46.46 hours: min/max  -3.14,   3.14
# t= 46.50 hours: min/max  -3.11,   3.16
# t= 46.54 hours: min/max  -3.09,   3.20
# t= 46.58 hours: min/max  -3.16,   3.20
# t= 46.62 hours: min/max  -3.19,   3.19
# t= 46.67 hours: min/max  -3.18,   3.16
# t= 46.71 hours: min/max  -3.14,   3.21
# t= 46.75 hours: min/max  -3.19,   3.23
# t= 46.79 hours: min/max  -3.23,   3.22
# t= 46.83 hours: min/max  -3.24,   3.18
# t= 46.88 hours: min/max  -3.21,   3.21
# t= 46.92 hours: min/max  -3.21,   3.25
# t= 46.96 hours: min/max  -3.26,   3.26
# t= 47.00 hours: min/max  -3.30,   3.22
# t= 47.04 hours: min/max  -3.28,   3.21
# t= 47.08 hours: min/max  -3.24,   3.27
# t= 47.12 hours: min/max  -3.29,   3.28
# t= 47.17 hours: min/max  -3.35,   3.26
# t= 47.21 hours: min/max  -3.34,   3.22
# t= 47.25 hours: min/max  -3.31,   3.28
# t= 47.29 hours: min/max  -3.32,   3.30
# t= 47.33 hours: min/max  -3.39,   3.30
# t= 47.38 hours: min/max  -3.39,   3.26
# t= 47.42 hours: min/max  -3.38,   3.28
# t= 47.46 hours: min/max  -3.35,   3.32
# t= 47.50 hours: min/max  -3.43,   3.33
# t= 47.54 hours: min/max  -3.45,   3.31
# t= 47.58 hours: min/max  -3.45,   3.28
# t= 47.62 hours: min/max  -3.40,   3.33
# t= 47.67 hours: min/max  -3.45,   3.36
# t= 47.71 hours: min/max  -3.50,   3.35
# t= 47.75 hours: min/max  -3.52,   3.30
# t= 47.79 hours: min/max  -3.47,   3.34
# t= 47.83 hours: min/max  -3.47,   3.39
# t= 47.88 hours: min/max  -3.54,   3.38
# t= 47.92 hours: min/max  -3.57,   3.35
# t= 47.96 hours: min/max  -3.54,   3.35
# t= 48.00 hours: min/max  -3.51,   3.40
# t= 48.04 hours: min/max  -3.57,   3.40
# t= 48.08 hours: min/max  -3.62,   3.40
# t= 48.12 hours: min/max  -3.61,   3.35
# t= 48.17 hours: min/max  -3.58,   3.41
# t= 48.21 hours: min/max  -3.59,   3.44
# t= 48.25 hours: min/max  -3.65,   3.44
# t= 48.29 hours: min/max  -3.67,   3.39
# t= 48.33 hours: min/max  -3.65,   3.42
# t= 48.38 hours: min/max  -3.61,   3.46
# t= 48.42 hours: min/max  -3.68,   3.48
# t= 48.46 hours: min/max  -3.73,   3.44
# t= 48.50 hours: min/max  -3.72,   3.42
# t= 48.54 hours: min/max  -3.67,   3.48
# t= 48.58 hours: min/max  -3.70,   3.51
# t= 48.62 hours: min/max  -3.77,   3.48
# t= 48.67 hours: min/max  -3.78,   3.45
# t= 48.71 hours: min/max  -3.74,   3.50
# t= 48.75 hours: min/max  -3.72,   3.53
# t= 48.79 hours: min/max  -3.81,   3.53
# t= 48.83 hours: min/max  -3.82,   3.50
# t= 48.88 hours: min/max  -3.82,   3.50
# t= 48.92 hours: min/max  -3.77,   3.55
# t= 48.96 hours: min/max  -3.83,   3.57
# t= 49.00 hours: min/max  -3.86,   3.55
# t= 49.04 hours: min/max  -3.88,   3.50
# t= 49.08 hours: min/max  -3.83,   3.56
# t= 49.12 hours: min/max  -3.85,   3.60
# t= 49.17 hours: min/max  -3.90,   3.60
# t= 49.21 hours: min/max  -3.94,   3.55
# t= 49.25 hours: min/max  -3.90,   3.57
# t= 49.29 hours: min/max  -3.87,   3.63
# t= 49.33 hours: min/max  -3.94,   3.63
# t= 49.38 hours: min/max  -3.99,   3.61
# t= 49.42 hours: min/max  -3.96,   3.58
# t= 49.46 hours: min/max  -3.92,   3.65
# t= 49.50 hours: min/max  -3.96,   3.66
# t= 49.54 hours: min/max  -4.02,   3.66
# t= 49.58 hours: min/max  -4.02,   3.60
# t= 49.62 hours: min/max  -4.00,   3.66
# t= 49.67 hours: min/max  -3.97,   3.69
# t= 49.71 hours: min/max  -4.05,   3.71
# t= 49.75 hours: min/max  -4.08,   3.66
# t= 49.79 hours: min/max  -4.07,   3.66
# t= 49.83 hours: min/max  -4.02,   3.72
# t= 49.88 hours: min/max  -4.07,   3.74
# t= 49.92 hours: min/max  -4.13,   3.71
# t= 49.96 hours: min/max  -4.13,   3.67
# t= 50.00 hours: min/max  -4.08,   3.74
# t= 50.04 hours: min/max  -4.08,   3.78
# t= 50.08 hours: min/max  -4.17,   3.75
# t= 50.12 hours: min/max  -4.19,   3.72
# t= 50.17 hours: min/max  -4.15,   3.75
# t= 50.21 hours: min/max  -4.13,   3.80
# t= 50.25 hours: min/max  -4.19,   3.80
# t= 50.29 hours: min/max  -4.23,   3.78
# t= 50.33 hours: min/max  -4.22,   3.75
# t= 50.38 hours: min/max  -4.18,   3.81
# t= 50.42 hours: min/max  -4.21,   3.84
# t= 50.46 hours: min/max  -4.26,   3.83
# t= 50.50 hours: min/max  -4.29,   3.77
# t= 50.54 hours: min/max  -4.25,   3.82
# t= 50.58 hours: min/max  -4.23,   3.88
# t= 50.62 hours: min/max  -4.29,   3.88
# t= 50.67 hours: min/max  -4.35,   3.83
# t= 50.71 hours: min/max  -4.32,   3.83
# t= 50.75 hours: min/max  -4.28,   3.90
# t= 50.79 hours: min/max  -4.32,   3.92
# t= 50.83 hours: min/max  -4.39,   3.89
# t= 50.88 hours: min/max  -4.37,   3.83
# t= 50.92 hours: min/max  -4.34,   3.92
# t= 50.96 hours: min/max  -4.33,   3.94
# t= 51.00 hours: min/max  -4.42,   3.94
# t= 51.04 hours: min/max  -4.42,   3.90
# t= 51.08 hours: min/max  -4.42,   3.93
# t= 51.12 hours: min/max  -4.39,   3.96
# t= 51.17 hours: min/max  -4.44,   3.99
# t= 51.21 hours: min/max  -4.48,   3.95
# ...
# t=127.08 hours: min/max -52.12,  46.95
# t=127.12 hours: min/max -52.05,  46.88
# t=127.17 hours: min/max -52.02,  46.90
# t=127.21 hours: min/max -52.00,  46.99
# t=127.25 hours: min/max -51.94,  47.00
# t=127.29 hours: min/max -51.85,  46.92
# t=127.33 hours: min/max -51.80,  46.89
# t=127.38 hours: min/max -51.78,  46.96
# t=127.42 hours: min/max -51.72,  47.00
# t=127.46 hours: min/max -51.63,  46.92
# t=127.50 hours: min/max -51.55,  46.84
# t=127.54 hours: min/max -51.52,  46.89
# t=127.58 hours: min/max -51.47,  46.94
# t=127.62 hours: min/max -51.37,  46.87
# t=127.67 hours: min/max -51.28,  46.76
# t=127.71 hours: min/max -51.23,  46.76
# t=127.75 hours: min/max -51.18,  46.81
# t=127.79 hours: min/max -51.09,  46.79
# t=127.83 hours: min/max -50.99,  46.75
# t=127.88 hours: min/max -50.92,  46.70
# t=127.92 hours: min/max -50.88,  46.75
# t=127.96 hours: min/max -50.81,  46.82
# t=128.00 hours: min/max -50.78,  46.78
# t=128.04 hours: min/max -50.80,  46.71
# t=128.08 hours: min/max -50.86,  46.72
# t=128.12 hours: min/max -50.87,  46.78
# t=128.17 hours: min/max -50.83,  46.77
# t=128.21 hours: min/max -50.83,  46.67
# t=128.25 hours: min/max -50.87,  46.64
# t=128.29 hours: min/max -50.89,  46.69
# t=128.33 hours: min/max -50.85,  46.69
# t=128.38 hours: min/max -50.82,  46.59
# t=128.42 hours: min/max -50.85,  46.53
# t=128.46 hours: min/max -50.87,  46.58
# t=128.50 hours: min/max -50.84,  46.70
# t=128.54 hours: min/max -50.79,  46.72
# t=128.58 hours: min/max -50.79,  46.64
# t=128.62 hours: min/max -50.82,  46.65
# t=128.67 hours: min/max -50.97,  46.75
# t=128.71 hours: min/max -50.73,  46.80
# t=128.75 hours: min/max -50.71,  46.72
# t=128.79 hours: min/max -50.73,  46.67
# t=128.83 hours: min/max -51.25,  46.75
# t=128.88 hours: min/max -51.00,  46.81
# t=128.92 hours: min/max -50.60,  46.74
# t=128.96 hours: min/max -50.61,  46.66
# t=129.00 hours: min/max -51.39,  46.70
# t=129.04 hours: min/max -51.42,  46.77
# t=129.08 hours: min/max -50.69,  46.72
# t=129.12 hours: min/max -50.63,  46.60
# t=129.17 hours: min/max -51.43,  46.59
# t=129.21 hours: min/max -51.73,  46.66
# t=129.25 hours: min/max -51.07,  46.63
# t=129.29 hours: min/max -50.73,  46.58
# t=129.33 hours: min/max -51.39,  46.52
# t=129.38 hours: min/max -51.91,  46.57
# t=129.42 hours: min/max -51.41,  46.65
# t=129.46 hours: min/max -50.85,  46.63
# t=129.50 hours: min/max -51.28,  46.55
# t=129.54 hours: min/max -51.95,  46.55
# t=129.58 hours: min/max -51.67,  46.62
# t=129.62 hours: min/max -50.98,  46.62
# t=129.67 hours: min/max -51.14,  46.53
# t=129.71 hours: min/max -51.86,  46.49
# t=129.75 hours: min/max -51.83,  46.55
# t=129.79 hours: min/max -51.11,  46.57
# t=129.83 hours: min/max -50.99,  46.48
# t=129.88 hours: min/max -51.66,  46.39
# t=129.92 hours: min/max -51.88,  46.42
# t=129.96 hours: min/max -51.38,  46.45
# t=130.00 hours: min/max -50.85,  46.46
# t=130.04 hours: min/max -51.39,  46.39
# t=130.08 hours: min/max -51.80,  46.39
# t=130.12 hours: min/max -51.80,  46.52
# t=130.17 hours: min/max -51.38,  46.59
# t=130.21 hours: min/max -51.05,  46.52
# t=130.25 hours: min/max -51.59,  46.47
# t=130.29 hours: min/max -52.11,  46.56
# t=130.33 hours: min/max -51.88,  46.64
# t=130.38 hours: min/max -51.33,  46.59
# t=130.42 hours: min/max -51.58,  46.50
# t=130.46 hours: min/max -52.30,  46.54
# t=130.50 hours: min/max -52.31,  46.63
# t=130.54 hours: min/max -51.71,  46.60
# t=130.58 hours: min/max -51.70,  46.47
# t=130.62 hours: min/max -52.40,  46.45
# t=130.67 hours: min/max -52.63,  46.54
# t=130.71 hours: min/max -52.08,  46.58
# t=130.75 hours: min/max -51.84,  46.56
# t=130.79 hours: min/max -52.41,  46.51
# t=130.83 hours: min/max -52.83,  46.55
# t=130.88 hours: min/max -52.41,  46.65
# t=130.92 hours: min/max -51.98,  46.65
# t=130.96 hours: min/max -52.37,  46.57
# t=131.00 hours: min/max -52.92,  46.56
# t=131.04 hours: min/max -52.68,  46.65
# t=131.08 hours: min/max -52.13,  46.66
# t=131.12 hours: min/max -52.30,  46.57
# t=131.17 hours: min/max -52.90,  46.51
# t=131.21 hours: min/max -52.86,  46.56
# t=131.25 hours: min/max -52.30,  46.59
# t=131.29 hours: min/max -52.21,  46.50
# t=131.33 hours: min/max -52.77,  46.40
# t=131.38 hours: min/max -52.95,  46.41
# t=131.42 hours: min/max -52.67,  46.44
# t=131.46 hours: min/max -52.11,  46.36
# t=131.50 hours: min/max -52.57,  46.22
# t=131.54 hours: min/max -53.03,  46.18
# t=131.58 hours: min/max -52.96,  46.28
# t=131.62 hours: min/max -52.35,  46.35
# t=131.67 hours: min/max -52.36,  46.26
# t=131.71 hours: min/max -53.01,  46.18
# t=131.75 hours: min/max -53.16,  46.23
# t=131.79 hours: min/max -52.58,  46.31
# t=131.83 hours: min/max -52.36,  46.24
# t=131.88 hours: min/max -52.91,  46.16
# t=131.92 hours: min/max -53.25,  46.14
# t=131.96 hours: min/max -52.79,  46.24
# t=132.00 hours: min/max -52.38,  46.33
# t=132.04 hours: min/max -52.77,  46.29
# t=132.08 hours: min/max -53.24,  46.23
# t=132.12 hours: min/max -52.93,  46.30
# t=132.17 hours: min/max -52.50,  46.38
# t=132.21 hours: min/max -52.59,  46.36
# t=132.25 hours: min/max -53.12,  46.28
# t=132.29 hours: min/max -53.19,  46.29
# t=132.33 hours: min/max -52.86,  46.37
# t=132.38 hours: min/max -52.56,  46.37
# t=132.42 hours: min/max -52.91,  46.27
# t=132.46 hours: min/max -53.35,  46.23
# t=132.50 hours: min/max -53.16,  46.29
# t=132.54 hours: min/max -52.75,  46.30
# t=132.58 hours: min/max -52.92,  46.20
# t=132.62 hours: min/max -53.41,  46.11
# t=132.67 hours: min/max -53.37,  46.14
# t=132.71 hours: min/max -52.92,  46.16
# t=132.75 hours: min/max -52.90,  46.11
# t=132.79 hours: min/max -53.36,  46.05
# t=132.83 hours: min/max -53.48,  46.03
# t=132.88 hours: min/max -53.24,  46.10
# t=132.92 hours: min/max -52.87,  46.13
# t=132.96 hours: min/max -53.24,  46.07
# t=133.00 hours: min/max -53.65,  46.01
# t=133.04 hours: min/max -53.58,  46.05
# t=133.08 hours: min/max -53.14,  46.09
# t=133.12 hours: min/max -53.21,  46.03
# t=133.17 hours: min/max -53.74,  45.94
# t=133.21 hours: min/max -53.85,  45.93
# t=133.25 hours: min/max -53.42,  45.96
# t=133.29 hours: min/max -53.31,  45.95
# t=133.33 hours: min/max -53.78,  45.90
# t=133.38 hours: min/max -54.03,  45.86
# t=133.42 hours: min/max -53.68,  45.94
# t=133.46 hours: min/max -53.41,  46.02
# t=133.50 hours: min/max -53.77,  45.97
# t=133.54 hours: min/max -54.13,  45.89
# t=133.58 hours: min/max -53.89,  45.92
# t=133.62 hours: min/max -53.52,  46.00
# t=133.67 hours: min/max -53.72,  45.96
# t=133.71 hours: min/max -54.14,  45.85
# t=133.75 hours: min/max -54.03,  45.82
# t=133.79 hours: min/max -53.61,  45.90
# t=133.83 hours: min/max -53.64,  45.98
# t=133.88 hours: min/max -54.06,  45.98
# t=133.92 hours: min/max -54.10,  45.94
# t=133.96 hours: min/max -53.68,  45.98
# t=134.00 hours: min/max -53.55,  46.06
# t=134.04 hours: min/max -53.91,  46.06
# t=134.08 hours: min/max -54.07,  46.00
# t=134.12 hours: min/max -53.70,  45.99
# t=134.17 hours: min/max -53.43,  46.06
# t=134.21 hours: min/max -53.69,  46.07
# t=134.25 hours: min/max -53.94,  45.99
# t=134.29 hours: min/max -53.68,  45.94
# t=134.33 hours: min/max -53.30,  45.98
# t=134.38 hours: min/max -53.42,  46.00
# t=134.42 hours: min/max -53.71,  45.92
# t=134.46 hours: min/max -53.81,  45.82
# t=134.50 hours: min/max -53.45,  45.82
# t=134.54 hours: min/max -53.26,  45.84
# t=134.58 hours: min/max -53.60,  45.76
# t=134.62 hours: min/max -53.86,  45.63
# t=134.67 hours: min/max -53.78,  45.59
# t=134.71 hours: min/max -53.49,  45.63
# t=134.75 hours: min/max -53.50,  45.67
# t=134.79 hours: min/max -53.86,  45.64
# t=134.83 hours: min/max -54.05,  45.58
# t=134.88 hours: min/max -53.79,  45.59
# t=134.92 hours: min/max -53.65,  45.71
# t=134.96 hours: min/max -53.96,  45.77
# t=135.00 hours: min/max -54.24,  45.75
# t=135.04 hours: min/max -54.06,  45.74
# t=135.08 hours: min/max -53.83,  45.83
# t=135.12 hours: min/max -54.03,  45.91
# t=135.17 hours: min/max -54.35,  45.87
# t=135.21 hours: min/max -54.27,  45.82
# t=135.25 hours: min/max -53.99,  45.87
# t=135.29 hours: min/max -54.07,  45.94
# t=135.33 hours: min/max -54.40,  45.91
# t=135.38 hours: min/max -54.41,  45.82
# t=135.42 hours: min/max -54.13,  45.81
# t=135.46 hours: min/max -54.08,  45.87
# t=135.50 hours: min/max -54.38,  45.84
# t=135.54 hours: min/max -54.49,  45.72
# t=135.58 hours: min/max -54.22,  45.70
# t=135.62 hours: min/max -54.07,  45.75
# t=135.67 hours: min/max -54.30,  45.83
# t=135.71 hours: min/max -54.47,  45.84
# t=135.75 hours: min/max -54.27,  45.80
# t=135.79 hours: min/max -54.03,  45.80
# t=135.83 hours: min/max -54.16,  45.86
# t=135.88 hours: min/max -54.37,  45.88
# t=135.92 hours: min/max -54.24,  45.82
# t=135.96 hours: min/max -53.95,  45.78
# t=136.00 hours: min/max -53.97,  45.81
# t=136.04 hours: min/max -54.19,  45.82
# t=136.08 hours: min/max -54.28,  45.74
# t=136.12 hours: min/max -54.11,  45.66
# t=136.17 hours: min/max -53.96,  45.65
# t=136.21 hours: min/max -54.18,  45.65
# t=136.25 hours: min/max -54.41,  45.58
# t=136.29 hours: min/max -54.30,  45.46
# t=136.33 hours: min/max -54.10,  45.41
# t=136.38 hours: min/max -54.22,  45.39
# t=136.42 hours: min/max -54.47,  45.38
# t=136.46 hours: min/max -54.43,  45.40
# t=136.50 hours: min/max -54.20,  45.39
# t=136.54 hours: min/max -54.22,  45.44
# t=136.58 hours: min/max -54.47,  45.54
# t=136.62 hours: min/max -54.50,  45.59
# t=136.67 hours: min/max -54.27,  45.56
# t=136.71 hours: min/max -54.20,  45.56
# t=136.75 hours: min/max -54.41,  45.63
# t=136.79 hours: min/max -54.50,  45.68
# t=136.83 hours: min/max -54.30,  45.64
# t=136.88 hours: min/max -54.15,  45.60
# t=136.92 hours: min/max -54.30,  45.63
# t=136.96 hours: min/max -54.43,  45.67
# t=137.00 hours: min/max -54.28,  45.62
# t=137.04 hours: min/max -54.10,  45.54
# t=137.08 hours: min/max -54.14,  45.52
# t=137.12 hours: min/max -54.30,  45.54
# t=137.17 hours: min/max -54.34,  45.50
# t=137.21 hours: min/max -54.18,  45.40
# t=137.25 hours: min/max -54.05,  45.39
# t=137.29 hours: min/max -54.18,  45.42
# t=137.33 hours: min/max -54.32,  45.47
# t=137.38 hours: min/max -54.21,  45.48
# t=137.42 hours: min/max -54.02,  45.44
# t=137.46 hours: min/max -54.07,  45.44
# t=137.50 hours: min/max -54.22,  45.47
# t=137.54 hours: min/max -54.16,  45.47
# t=137.58 hours: min/max -53.95,  45.42
# t=137.62 hours: min/max -53.92,  45.37
# t=137.67 hours: min/max -54.05,  45.38
# t=137.71 hours: min/max -54.03,  45.37
# t=137.75 hours: min/max -53.82,  45.31
# t=137.79 hours: min/max -53.71,  45.23
# t=137.83 hours: min/max -53.81,  45.20
# t=137.88 hours: min/max -53.97,  45.19
# t=137.92 hours: min/max -53.94,  45.18
# t=137.96 hours: min/max -53.84,  45.13
# t=138.00 hours: min/max -53.93,  45.15
# t=138.04 hours: min/max -54.11,  45.22
# t=138.08 hours: min/max -54.13,  45.31
# t=138.12 hours: min/max -54.01,  45.35
# t=138.17 hours: min/max -54.04,  45.35
# t=138.21 hours: min/max -54.21,  45.38
# t=138.25 hours: min/max -54.26,  45.45
# t=138.29 hours: min/max -54.15,  45.49
# t=138.33 hours: min/max -54.11,  45.47
# t=138.38 hours: min/max -54.25,  45.45
# t=138.42 hours: min/max -54.33,  45.49
# t=138.46 hours: min/max -54.23,  45.52
# t=138.50 hours: min/max -54.15,  45.48
# t=138.54 hours: min/max -54.25,  45.43
# t=138.58 hours: min/max -54.35,  45.44
# t=138.62 hours: min/max -54.27,  45.45
# t=138.67 hours: min/max -54.16,  45.40
# t=138.71 hours: min/max -54.21,  45.32
# t=138.75 hours: min/max -54.31,  45.27
# t=138.79 hours: min/max -54.26,  45.26
# t=138.83 hours: min/max -54.13,  45.30
# t=138.88 hours: min/max -54.12,  45.31
# t=138.92 hours: min/max -54.22,  45.30
# t=138.96 hours: min/max -54.20,  45.32
# t=139.00 hours: min/max -54.06,  45.35
# t=139.04 hours: min/max -54.00,  45.35
# t=139.08 hours: min/max -54.08,  45.32
# t=139.12 hours: min/max -54.08,  45.31
# t=139.17 hours: min/max -53.94,  45.32
# t=139.21 hours: min/max -53.85,  45.34
# t=139.25 hours: min/max -53.89,  45.34
# t=139.29 hours: min/max -53.92,  45.32
# t=139.33 hours: min/max -53.79,  45.35
# t=139.38 hours: min/max -53.66,  45.40
# t=139.42 hours: min/max -53.67,  45.38
# t=139.46 hours: min/max -53.70,  45.33
# t=139.50 hours: min/max -53.74,  45.36
# t=139.54 hours: min/max -53.71,  45.45
# t=139.58 hours: min/max -53.72,  45.53
# t=139.62 hours: min/max -53.82,  45.57
# t=139.67 hours: min/max -53.88,  45.58
# t=139.71 hours: min/max -53.85,  45.63
# t=139.75 hours: min/max -53.83,  45.69
# t=139.79 hours: min/max -53.91,  45.72
# t=139.83 hours: min/max -53.97,  45.71
# t=139.88 hours: min/max -53.94,  45.72
# t=139.92 hours: min/max -53.90,  45.76
# t=139.96 hours: min/max -53.95,  45.77
# t=140.00 hours: min/max -54.01,  45.74
# t=140.04 hours: min/max -53.98,  45.71
# t=140.08 hours: min/max -53.93,  45.71
# t=140.12 hours: min/max -53.94,  45.71
# t=140.17 hours: min/max -53.99,  45.65
# t=140.21 hours: min/max -53.96,  45.59
# t=140.25 hours: min/max -53.89,  45.56
# t=140.29 hours: min/max -53.88,  45.53
# t=140.33 hours: min/max -53.91,  45.46
# t=140.38 hours: min/max -53.93,  45.44
# t=140.42 hours: min/max -53.89,  45.48
# t=140.46 hours: min/max -53.82,  45.55
# t=140.50 hours: min/max -53.83,  45.64
# t=140.54 hours: min/max -53.89,  45.70
# t=140.58 hours: min/max -53.85,  45.71
# t=140.62 hours: min/max -53.76,  45.74
# t=140.67 hours: min/max -53.73,  45.81
# t=140.71 hours: min/max -53.77,  45.85
# t=140.75 hours: min/max -53.75,  45.84
# t=140.79 hours: min/max -53.64,  45.83
# t=140.83 hours: min/max -53.57,  45.86
# t=140.88 hours: min/max -53.59,  45.88
# t=140.92 hours: min/max -53.57,  45.85
# t=140.96 hours: min/max -53.46,  45.81
# t=141.00 hours: min/max -53.36,  45.80
# t=141.04 hours: min/max -53.35,  45.79
# t=141.08 hours: min/max -53.34,  45.80
# t=141.12 hours: min/max -53.23,  45.84
# t=141.17 hours: min/max -53.10,  45.86
# t=141.21 hours: min/max -53.06,  45.91
# t=141.25 hours: min/max -53.04,  45.97
# t=141.29 hours: min/max -52.94,  45.98
# t=141.33 hours: min/max -52.80,  45.98
# t=141.38 hours: min/max -52.77,  45.99
# t=141.42 hours: min/max -52.84,  46.02
# t=141.46 hours: min/max -52.85,  46.02
# t=141.50 hours: min/max -52.83,  45.99
# t=141.54 hours: min/max -52.84,  45.97
# t=141.58 hours: min/max -52.91,  45.97
# t=141.62 hours: min/max -52.93,  45.96
# t=141.67 hours: min/max -52.89,  45.90
# t=141.71 hours: min/max -52.89,  45.85
# t=141.75 hours: min/max -52.94,  45.81
# t=141.79 hours: min/max -52.97,  45.77
# t=141.83 hours: min/max -52.93,  45.83
# t=141.88 hours: min/max -52.90,  45.88
# t=141.92 hours: min/max -52.94,  45.92
# t=141.96 hours: min/max -52.98,  46.00
# t=142.00 hours: min/max -52.94,  46.07
# t=142.04 hours: min/max -52.89,  46.10
# t=142.08 hours: min/max -52.91,  46.12
# t=142.12 hours: min/max -52.95,  46.15
# t=142.17 hours: min/max -52.92,  46.20
# t=142.21 hours: min/max -52.86,  46.22
# t=142.25 hours: min/max -52.85,  46.20
# t=142.29 hours: min/max -52.89,  46.20
# t=142.33 hours: min/max -52.87,  46.22
# t=142.38 hours: min/max -52.79,  46.22
# t=142.42 hours: min/max -52.76,  46.18
# t=142.46 hours: min/max -52.79,  46.14
# t=142.50 hours: min/max -52.78,  46.12
# t=142.54 hours: min/max -52.69,  46.10
# t=142.58 hours: min/max -52.63,  46.03
# t=142.62 hours: min/max -52.64,  45.96
# t=142.67 hours: min/max -52.64,  45.90
# t=142.71 hours: min/max -52.55,  45.85
# t=142.75 hours: min/max -52.47,  45.88
# t=142.79 hours: min/max -52.45,  45.88
# t=142.83 hours: min/max -52.45,  45.89
# t=142.88 hours: min/max -52.38,  45.91
# t=142.92 hours: min/max -52.27,  45.98
# t=142.96 hours: min/max -52.23,  46.02
# t=143.00 hours: min/max -52.23,  46.02
# t=143.04 hours: min/max -52.16,  46.03
# t=143.08 hours: min/max -52.04,  46.07
# t=143.12 hours: min/max -51.96,  46.09
# t=143.17 hours: min/max -51.95,  46.06
# t=143.21 hours: min/max -51.90,  46.04
# t=143.25 hours: min/max -51.79,  46.04
# t=143.29 hours: min/max -51.81,  46.03
# t=143.33 hours: min/max -51.90,  45.98
# t=143.38 hours: min/max -51.93,  45.96
# t=143.42 hours: min/max -51.87,  46.02
# t=143.46 hours: min/max -51.86,  46.09
# t=143.50 hours: min/max -51.93,  46.14
# t=143.54 hours: min/max -51.98,  46.17
# t=143.58 hours: min/max -51.93,  46.19
# t=143.62 hours: min/max -51.88,  46.23
# t=143.67 hours: min/max -51.92,  46.27
# t=143.71 hours: min/max -51.98,  46.27
# t=143.75 hours: min/max -51.94,  46.26
# t=143.79 hours: min/max -51.87,  46.27
# t=143.83 hours: min/max -51.88,  46.28
# t=143.88 hours: min/max -51.94,  46.26
# t=143.92 hours: min/max -51.92,  46.22
# t=143.96 hours: min/max -51.86,  46.20
# t=144.00 hours: min/max -51.80,  46.18
# ('CPU time = ', 61.967617000000004)
# ('max/min PV', -0.9878470980682046, 1.7918748161688125)
