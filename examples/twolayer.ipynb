# %%
from __future__ import print_function
import numpy as np
from spharm import Spharmt, getspecindx, gaussian_lats_wts

# two-layer baroclinic primitive equation model of
# Zou., X. A., A. Barcilon, I. M. Navon, J. S. Whitaker, and D. G. Cacuci,
# 1993: An adjoint sensitivity study of blocking in a two-layer isentropic
# model. Mon. Wea. Rev., 121, 2834-2857.
# doi: http://dx.doi.org/10.1175/1520-0493(1993)121<2833:AASSOB>2.0.CO;2

class TwoLayer(object):

    def __init__(self,sp,dt,ntrunc,theta1=300,theta2=330,grav=9.80616,omega=7.292e-5,cp=1004,\
            zmid=5.e3,ztop=15.e3,efold=3600.,ndiss=8,tdrag=1.e30,tdiab=1.e30,umax=30,jetexp=4):
        # setup model parameters
        self.theta1 = theta1 # lower layer pot. temp.
        self.theta2 = theta2 # upper layer pot. temp.
        self.delth = theta2-theta1 # difference in potential temp between layers
        self.grav = grav # gravity
        self.omega = omega # rotation rate
        self.cp = cp # Specific Heat of Dry Air at Constant Pressure,
        self.zmid = zmid # resting depth of lower layer (m)
        self.ztop = ztop # resting depth of both layers (m)
        # efolding time scale for hyperdiffusion at shortest wavenumber
        self.efold = efold
        self.ndiss = ndiss # order of hyperdiffusion (2 for laplacian)
        self.sp = sp # Spharmt instance
        self.ntrunc = ntrunc # triangular truncation wavenumber
        self.dt = dt # time step (secs)
        self.tdiab = tdiab # lower layer drag timescale
        self.tdrag = tdrag # interface relaxation timescale
        # create lat/lon arrays
        delta = 2.*np.pi/sp.nlon
        if sp.gridtype == 'regular':
           lats1d = 0.5*np.pi-delta*np.arange(sp.nlat)
        else:
           lats1d,wts = gaussian_lats_wts(sp.nlat)
           lats1d = lats1d*np.pi/180.
        lons1d = np.arange(-np.pi,np.pi,delta)
        lons,lats = np.meshgrid(lons1d,lats1d)
        self.lons = lons
        self.lats = lats
        self.f = 2.*omega*np.sin(lats)[:,:,np.newaxis] # coriolis
        # create laplacian operator and its inverse.
        indxm, indxn = getspecindx(ntrunc)
        indxn = indxn.astype(np.float32)[:,np.newaxis]
        totwavenum = indxn*(indxn+1.0)
        self.lap = -totwavenum/sp.rsphere**2
        self.ilap = np.zeros(self.lap.shape, np.float32)
        self.ilap[1:,:] = 1./self.lap[1:,:]
        # hyperdiffusion operator
        self.hyperdiff = -(1./efold)*(totwavenum/totwavenum[-1])**(ndiss/2)
        # initialize orography to zero.
        self.orog = np.zeros((sp.nlat,sp.nlon),np.float32)
        # set equilibrium layer thicknes profile.
        self._interface_profile(umax,jetexp)

    def _interface_profile(self,umax,jetexp):
        ug = np.zeros((self.sp.nlat,self.sp.nlon,2),np.float32)
        vg = np.zeros((self.sp.nlat,self.sp.nlon,2),np.float32)
        ug[:,:,1] = umax*np.sin(2.*self.lats)**jetexp
        vrtspec, divspec = self.sp.getvrtdivspec(ug,vg,self.ntrunc)
        lyrthkspec = self.nlbalance(vrtspec)
        self.lyrthkref = self.sp.spectogrd(lyrthkspec)
        self.uref = ug
        if self.lyrthkref.min() < 0:
            raise ValueError('negative layer thickness! adjust equilibrium jet parameter')

    def nlbalance(self,vrtspec):
        # solve nonlinear balance eqn to get layer thickness given vorticity.
        divspec = np.zeros(vrtspec.shape, vrtspec.dtype)
        lyrthkspec = np.zeros(vrtspec.shape, vrtspec.dtype)
        vrtg = self.sp.spectogrd(vrtspec)
        ug,vg = self.sp.getuv(vrtspec,divspec)
        tmpg1 = ug*(vrtg+self.f); tmpg2 = vg*(vrtg+self.f)
        tmpspec1, tmpspec2 = self.sp.getvrtdivspec(tmpg1,tmpg2,self.ntrunc)
        tmpspec2 = self.sp.grdtospec(0.5*(ug**2+vg**2),self.ntrunc)
        mspec = self.ilap*tmpspec1 - tmpspec2
        lyrthkspec[:,0] =\
        (mspec[:,0]-self.sp.grdtospec(self.grav*self.orog,self.ntrunc))/self.theta1
        lyrthkspec[:,1] = (mspec[:,1]-mspec[:,0])/self.delth
        lyrthkspec[:,0] = lyrthkspec[:,0] - lyrthkspec[:,1]
        exnftop = self.cp - (self.grav*self.ztop/self.theta1)
        exnfmid = self.cp - (self.grav*self.zmid/self.theta1)
        lyrthkspec[0,0] = (2./np.sqrt(2.))*(self.cp - exnfmid)
        lyrthkspec[0,1] = (2./np.sqrt(2.))*(exnfmid - exnftop)
        lyrthkspec = (self.theta1/self.grav)*lyrthkspec # convert from exner function to height units (m)
        return lyrthkspec

    def gettend(self,vrtspec,divspec,lyrthkspec):
        # compute tendencies.
        # first, transform fields from spectral space to grid space.
        vrtg = self.sp.spectogrd(vrtspec)
        ug,vg = self.sp.getuv(vrtspec,divspec)
        lyrthkg = self.sp.spectogrd(lyrthkspec)
        self.u = ug; self.v = vg
        self.vrt = vrtg; self.lyrthk = lyrthkg
        if self.tdiab < 1.e10:
            totthk = lyrthkg.sum(axis=2)
            thtadot = self.delth*(self.lyrthkref[:,:,1] - lyrthkg[:,:,1])/\
                                (self.tdiab*totthk)
        # horizontal vorticity flux
        tmpg1 = ug*(vrtg+self.f); tmpg2 = vg*(vrtg+self.f)
        # add lower layer drag contribution
        if self.tdrag < 1.e10:
            tmpg1[:,:,0] += vg[:,:,0]/self.tdrag
            tmpg2[:,:,0] += -ug[:,:,0]/self.tdrag
        # add diabatic momentum flux contribution
        if self.tdiab < 1.e10:
            tmpg1 += 0.5*(vg[:,:,1]-vg[:,:,0])[:,:,np.newaxis]*\
            thtadot[:,:,np.newaxis]*totthk[:,:,np.newaxis]/(self.delth*lyrthkg)
            tmpg2 += -0.5*(ug[:,:,1]-ug[:,:,0])[:,:,np.newaxis]*\
            thtadot[:,:,np.newaxis]*totthk[:,:,np.newaxis]/(self.delth*lyrthkg)
        # compute vort flux contributions to vorticity and divergence tend.
        ddivdtspec, dvrtdtspec = self.sp.getvrtdivspec(tmpg1,tmpg2,self.ntrunc)
        dvrtdtspec *= -1
        # vorticity hyperdiffusion
        dvrtdtspec += self.hyperdiff*vrtspec
        # horizontal mass flux contribution to continuity
        tmpg1 = ug*lyrthkg; tmpg2 = vg*lyrthkg
        tmpspec, dlyrthkdtspec = self.sp.getvrtdivspec(tmpg1,tmpg2,self.ntrunc)
        dlyrthkdtspec *= -1
        # diabatic mass flux contribution to continuity
        if self.tdiab < 1.e10:
            tmpspec = self.sp.grdtospec(thtadot*totthk/self.delth,self.ntrunc)
            dlyrthkdtspec[:,0] += -tmpspec; dlyrthkdtspec[:,1] += tmpspec
        # pressure gradient force contribution to divergence tend (includes
        # orography).
        mstrm = np.empty((self.sp.nlat,self.sp.nlon,2),np.float32)
        mstrm[:,:,0] = self.grav*(self.orog + lyrthkg[:,:,0] + lyrthkg[:,:,1])
        mstrm[:,:,1] = mstrm[:,:,0] + (self.grav*self.delth/self.theta1)*lyrthkg[:,:,1]
        ddivdtspec += -self.lap*self.sp.grdtospec(mstrm+0.5*(ug**2+vg**2),self.ntrunc)
        # divergence hyperdiffusion
        ddivdtspec += self.hyperdiff*divspec
        return dvrtdtspec,ddivdtspec,dlyrthkdtspec

    def rk4step(self,vrtspec,divspec,lyrthkspec):
        # update state using 4th order runge-kutta
        dt = self.dt
        k1vrt,k1div,k1thk = \
        self.gettend(vrtspec,divspec,lyrthkspec)
        k2vrt,k2div,k2thk = \
        self.gettend(vrtspec+0.5*dt*k1vrt,divspec+0.5*dt*k1div,lyrthkspec+0.5*dt*k1thk)
        k3vrt,k3div,k3thk = \
        self.gettend(vrtspec+0.5*dt*k2vrt,divspec+0.5*dt*k2div,lyrthkspec+0.5*dt*k2thk)
        k4vrt,k4div,k4thk = \
        self.gettend(vrtspec+dt*k3vrt,divspec+dt*k3div,lyrthkspec+dt*k3thk)
        vrtspec += dt*(k1vrt+2.*k2vrt+2.*k3vrt+k4vrt)/6.
        divspec += dt*(k1div+2.*k2div+2.*k3div+k4div)/6.
        lyrthkspec += dt*(k1thk+2.*k2thk+2.*k3thk+k4thk)/6.
        return vrtspec,divspec,lyrthkspec

if __name__ == "__main__":
    import matplotlib.pyplot as plt
    from mpl_toolkits.basemap import Basemap, addcyclic
    import time

    # grid, time step info
    nlons = 128  # number of longitudes
    ntrunc = 42 # spectral truncation (for alias-free computations)
    nlats = (nlons/2)+1 # for regular grid.
    gridtype = 'regular'
    #nlats = nlons/2 # for gaussian grid.
    #gridtype = 'gaussian'
    dt = 900 # time step in seconds
    itmax = 8*(86400/dt) # integration length in days
    umax = 50. # jet speed
    jetexp = 10 # parameter controlling jet width

    # create spherical harmonic instance.
    rsphere = 6.37122e6 # earth radius
    sp = Spharmt(nlons,nlats,rsphere=rsphere,gridtype=gridtype)

    # create model instance using default parameters.
    model = TwoLayer(sp,dt,ntrunc)

    # vort, div initial conditions
    psipert = np.zeros((sp.nlat,sp.nlon,2),np.float32)
    psipert[:,:,1] = 5.e6*np.sin((model.lons-np.pi))**12*np.sin(2.*model.lats)**12
    psipert = np.where(model.lons[:,:,np.newaxis] > 0., 0, psipert)
    ug = np.zeros((sp.nlat,sp.nlon,2),np.float32)
    vg = np.zeros((sp.nlat,sp.nlon,2),np.float32)
    ug[:,:,1] = umax*np.sin(2.*model.lats)**jetexp
    vrtspec, divspec = sp.getvrtdivspec(ug,vg,model.ntrunc)
    vrtspec = vrtspec + model.lap*sp.grdtospec(psipert,model.ntrunc)
    vrtg = sp.spectogrd(vrtspec)
    lyrthkspec = model.nlbalance(vrtspec)
    lyrthkg = sp.spectogrd(lyrthkspec)
    print(lyrthkg[:,:,0].min(), lyrthkg[:,:,0].max())
    print(lyrthkg[:,:,1].min(), lyrthkg[:,:,1].max())
    if lyrthkg.min() < 0:
        raise ValueError('negative layer thickness! adjust jet parameters')

    # time loop.
    time1 = time.clock()
    for ncycle in range(itmax+1):
        t = ncycle*model.dt
        vrtspec, divspec, lyrthkspec = model.rk4step(vrtspec, divspec, lyrthkspec)
        pvg = (0.5*model.zmid/model.omega)*(model.vrt + model.f)/model.lyrthk
        print('t=%6.2f hours: v min/max %6.2f, %6.2f pv min/max %6.2f, %6.2f'%\
        (t/3600.,model.v.min(), model.v.max(), pvg.min(), pvg.max()))
    time2 = time.clock()
    print('CPU time = ',time2-time1)

    # make a plot of upper layer thickness
    m = Basemap(projection='ortho',lat_0=60,lon_0=180)
    lons1d = model.lons[0,:]*180./np.pi
    lats1d = model.lats[:,0]*180./np.pi
    lyrthk,lons1dx = addcyclic(model.lyrthk[:,:,1],lons1d)
    print('max/min upper layer thk',lyrthk.min(), lyrthk.max())
    lons, lats = np.meshgrid(lons1dx,lats1d)
    x,y = m(lons,lats)
    m.drawmeridians(np.arange(-180,180,60))
    m.drawparallels(np.arange(-80,81,20))
    CS=m.contourf(x,y,lyrthk,30,cmap=plt.cm.get_cmap("Spectral"),extend='both')
    m.colorbar()
    plt.title('Upper-Layer Thickness (T%s, hour %6.2f)' % (ntrunc,t/3600.))
    plt.show()
# Out:
# 1143.1133 14709.394
# 290.60495 13856.887
# t=  0.00 hours: v min/max  -2.41,   2.37 pv min/max -14.51,  16.85
# t=  0.25 hours: v min/max  -2.44,   2.35 pv min/max -14.51,  16.85
# t=  0.50 hours: v min/max  -2.46,   2.33 pv min/max -14.51,  16.85
# t=  0.75 hours: v min/max  -2.48,   2.30 pv min/max -14.51,  16.85
# t=  1.00 hours: v min/max  -2.49,   2.27 pv min/max -14.51,  16.85
# t=  1.25 hours: v min/max  -2.50,   2.24 pv min/max -14.51,  16.85
# t=  1.50 hours: v min/max  -2.53,   2.22 pv min/max -14.51,  16.85
# t=  1.75 hours: v min/max  -2.55,   2.21 pv min/max -14.51,  16.85
# t=  2.00 hours: v min/max  -2.58,   2.19 pv min/max -14.51,  16.85
# t=  2.25 hours: v min/max  -2.60,   2.18 pv min/max -14.51,  16.85
# t=  2.50 hours: v min/max  -2.62,   2.17 pv min/max -14.51,  16.85
# t=  2.75 hours: v min/max  -2.64,   2.15 pv min/max -14.51,  16.85
# t=  3.00 hours: v min/max  -2.65,   2.14 pv min/max -14.51,  16.85
# t=  3.25 hours: v min/max  -2.66,   2.13 pv min/max -14.51,  16.85
# t=  3.50 hours: v min/max  -2.67,   2.11 pv min/max -14.51,  16.85
# t=  3.75 hours: v min/max  -2.68,   2.10 pv min/max -14.51,  16.85
# t=  4.00 hours: v min/max  -2.69,   2.09 pv min/max -14.51,  16.85
# t=  4.25 hours: v min/max  -2.70,   2.08 pv min/max -14.51,  16.85
# t=  4.50 hours: v min/max  -2.71,   2.07 pv min/max -14.51,  16.85
# t=  4.75 hours: v min/max  -2.72,   2.06 pv min/max -14.51,  16.85
# t=  5.00 hours: v min/max  -2.73,   2.05 pv min/max -14.51,  16.85
# t=  5.25 hours: v min/max  -2.74,   2.05 pv min/max -14.51,  16.85
# t=  5.50 hours: v min/max  -2.74,   2.05 pv min/max -14.51,  16.85
# t=  5.75 hours: v min/max  -2.75,   2.04 pv min/max -14.51,  16.85
# t=  6.00 hours: v min/max  -2.76,   2.03 pv min/max -14.51,  16.85
# t=  6.25 hours: v min/max  -2.78,   2.03 pv min/max -14.51,  16.85
# t=  6.50 hours: v min/max  -2.79,   2.02 pv min/max -14.51,  16.85
# t=  6.75 hours: v min/max  -2.80,   2.01 pv min/max -14.51,  16.85
# t=  7.00 hours: v min/max  -2.82,   2.01 pv min/max -14.51,  16.85
# t=  7.25 hours: v min/max  -2.83,   2.00 pv min/max -14.51,  16.85
# t=  7.50 hours: v min/max  -2.84,   1.99 pv min/max -14.51,  16.85
# t=  7.75 hours: v min/max  -2.84,   1.97 pv min/max -14.51,  16.85
# t=  8.00 hours: v min/max  -2.85,   1.96 pv min/max -14.51,  16.85
# t=  8.25 hours: v min/max  -2.85,   1.95 pv min/max -14.51,  16.85
# t=  8.50 hours: v min/max  -2.86,   1.93 pv min/max -14.51,  16.85
# t=  8.75 hours: v min/max  -2.86,   1.92 pv min/max -14.51,  16.85
# t=  9.00 hours: v min/max  -2.86,   1.90 pv min/max -14.51,  16.85
# t=  9.25 hours: v min/max  -2.87,   1.89 pv min/max -14.51,  16.85
# t=  9.50 hours: v min/max  -2.87,   1.87 pv min/max -14.51,  16.85
# t=  9.75 hours: v min/max  -2.88,   1.86 pv min/max -14.51,  16.85
# t= 10.00 hours: v min/max  -2.89,   1.85 pv min/max -14.51,  16.85
# t= 10.25 hours: v min/max  -2.90,   1.84 pv min/max -14.51,  16.85
# t= 10.50 hours: v min/max  -2.91,   1.82 pv min/max -14.51,  16.85
# t= 10.75 hours: v min/max  -2.92,   1.81 pv min/max -14.51,  16.85
# t= 11.00 hours: v min/max  -2.93,   1.79 pv min/max -14.51,  16.85
# t= 11.25 hours: v min/max  -2.94,   1.78 pv min/max -14.51,  16.85
# t= 11.50 hours: v min/max  -2.94,   1.77 pv min/max -14.51,  16.85
# t= 11.75 hours: v min/max  -2.95,   1.75 pv min/max -14.51,  16.85
# t= 12.00 hours: v min/max  -2.95,   1.74 pv min/max -14.51,  16.85
# t= 12.25 hours: v min/max  -2.96,   1.73 pv min/max -14.51,  16.85
# t= 12.50 hours: v min/max  -2.96,   1.71 pv min/max -14.51,  16.85
# t= 12.75 hours: v min/max  -2.96,   1.71 pv min/max -14.51,  16.85
# t= 13.00 hours: v min/max  -2.98,   1.70 pv min/max -14.51,  16.85
# t= 13.25 hours: v min/max  -2.99,   1.70 pv min/max -14.51,  16.85
# t= 13.50 hours: v min/max  -3.00,   1.70 pv min/max -14.51,  16.85
# t= 13.75 hours: v min/max  -3.02,   1.69 pv min/max -14.51,  16.85
# t= 14.00 hours: v min/max  -3.03,   1.69 pv min/max -14.51,  16.85
# t= 14.25 hours: v min/max  -3.04,   1.69 pv min/max -14.51,  16.85
# t= 14.50 hours: v min/max  -3.06,   1.68 pv min/max -14.51,  16.85
# t= 14.75 hours: v min/max  -3.07,   1.68 pv min/max -14.51,  16.86
# t= 15.00 hours: v min/max  -3.08,   1.68 pv min/max -14.51,  16.86
# t= 15.25 hours: v min/max  -3.09,   1.68 pv min/max -14.51,  16.86
# t= 15.50 hours: v min/max  -3.09,   1.68 pv min/max -14.51,  16.86
# t= 15.75 hours: v min/max  -3.10,   1.68 pv min/max -14.51,  16.85
# t= 16.00 hours: v min/max  -3.11,   1.68 pv min/max -14.51,  16.85
# t= 16.25 hours: v min/max  -3.11,   1.68 pv min/max -14.51,  16.85
# t= 16.50 hours: v min/max  -3.12,   1.69 pv min/max -14.51,  16.85
# t= 16.75 hours: v min/max  -3.12,   1.70 pv min/max -14.51,  16.85
# t= 17.00 hours: v min/max  -3.13,   1.71 pv min/max -14.51,  16.85
# t= 17.25 hours: v min/max  -3.15,   1.71 pv min/max -14.51,  16.85
# t= 17.50 hours: v min/max  -3.16,   1.72 pv min/max -14.51,  16.85
# t= 17.75 hours: v min/max  -3.17,   1.72 pv min/max -14.51,  16.85
# t= 18.00 hours: v min/max  -3.18,   1.73 pv min/max -14.51,  16.85
# t= 18.25 hours: v min/max  -3.19,   1.73 pv min/max -14.51,  16.85
# t= 18.50 hours: v min/max  -3.20,   1.73 pv min/max -14.52,  16.85
# t= 18.75 hours: v min/max  -3.20,   1.73 pv min/max -14.52,  16.85
# t= 19.00 hours: v min/max  -3.21,   1.73 pv min/max -14.52,  16.85
# t= 19.25 hours: v min/max  -3.21,   1.73 pv min/max -14.52,  16.85
# t= 19.50 hours: v min/max  -3.21,   1.73 pv min/max -14.52,  16.85
# t= 19.75 hours: v min/max  -3.22,   1.73 pv min/max -14.52,  16.85
# t= 20.00 hours: v min/max  -3.21,   1.72 pv min/max -14.52,  16.85
# t= 20.25 hours: v min/max  -3.21,   1.71 pv min/max -14.51,  16.85
# t= 20.50 hours: v min/max  -3.21,   1.71 pv min/max -14.51,  16.85
# t= 20.75 hours: v min/max  -3.21,   1.71 pv min/max -14.51,  16.85
# t= 21.00 hours: v min/max  -3.21,   1.71 pv min/max -14.51,  16.85
# t= 21.25 hours: v min/max  -3.21,   1.71 pv min/max -14.51,  16.85
# t= 21.50 hours: v min/max  -3.22,   1.70 pv min/max -14.51,  16.85
# t= 21.75 hours: v min/max  -3.23,   1.70 pv min/max -14.51,  16.85
# t= 22.00 hours: v min/max  -3.24,   1.70 pv min/max -14.51,  16.85
# t= 22.25 hours: v min/max  -3.25,   1.69 pv min/max -14.51,  16.85
# t= 22.50 hours: v min/max  -3.26,   1.69 pv min/max -14.51,  16.85
# t= 22.75 hours: v min/max  -3.27,   1.68 pv min/max -14.51,  16.85
# t= 23.00 hours: v min/max  -3.27,   1.68 pv min/max -14.51,  16.85
# t= 23.25 hours: v min/max  -3.28,   1.70 pv min/max -14.51,  16.85
# t= 23.50 hours: v min/max  -3.28,   1.72 pv min/max -14.51,  16.85
# t= 23.75 hours: v min/max  -3.29,   1.74 pv min/max -14.51,  16.86
# t= 24.00 hours: v min/max  -3.30,   1.75 pv min/max -14.51,  16.86
# t= 24.25 hours: v min/max  -3.30,   1.77 pv min/max -14.51,  16.86
# t= 24.50 hours: v min/max  -3.31,   1.79 pv min/max -14.51,  16.86
# t= 24.75 hours: v min/max  -3.33,   1.81 pv min/max -14.51,  16.86
# t= 25.00 hours: v min/max  -3.34,   1.83 pv min/max -14.51,  16.86
# t= 25.25 hours: v min/max  -3.36,   1.85 pv min/max -14.51,  16.86
# t= 25.50 hours: v min/max  -3.37,   1.87 pv min/max -14.51,  16.85
# t= 25.75 hours: v min/max  -3.38,   1.88 pv min/max -14.51,  16.85
# t= 26.00 hours: v min/max  -3.39,   1.90 pv min/max -14.51,  16.85
# t= 26.25 hours: v min/max  -3.41,   1.92 pv min/max -14.51,  16.85
# t= 26.50 hours: v min/max  -3.44,   1.94 pv min/max -14.51,  16.85
# t= 26.75 hours: v min/max  -3.46,   1.96 pv min/max -14.51,  16.85
# t= 27.00 hours: v min/max  -3.48,   1.99 pv min/max -14.51,  16.85
# t= 27.25 hours: v min/max  -3.50,   2.01 pv min/max -14.51,  16.85
# t= 27.50 hours: v min/max  -3.53,   2.04 pv min/max -14.51,  16.85
# t= 27.75 hours: v min/max  -3.55,   2.06 pv min/max -14.51,  16.85
# t= 28.00 hours: v min/max  -3.57,   2.08 pv min/max -14.51,  16.85
# t= 28.25 hours: v min/max  -3.59,   2.11 pv min/max -14.51,  16.85
# t= 28.50 hours: v min/max  -3.61,   2.13 pv min/max -14.51,  16.85
# t= 28.75 hours: v min/max  -3.62,   2.15 pv min/max -14.51,  16.85
# t= 29.00 hours: v min/max  -3.64,   2.18 pv min/max -14.51,  16.85
# t= 29.25 hours: v min/max  -3.65,   2.21 pv min/max -14.51,  16.85
# t= 29.50 hours: v min/max  -3.66,   2.24 pv min/max -14.51,  16.85
# t= 29.75 hours: v min/max  -3.68,   2.27 pv min/max -14.51,  16.85
# t= 30.00 hours: v min/max  -3.69,   2.30 pv min/max -14.51,  16.85
# t= 30.25 hours: v min/max  -3.71,   2.33 pv min/max -14.51,  16.85
# t= 30.50 hours: v min/max  -3.71,   2.36 pv min/max -14.51,  16.85
# t= 30.75 hours: v min/max  -3.72,   2.39 pv min/max -14.51,  16.85
# t= 31.00 hours: v min/max  -3.73,   2.41 pv min/max -14.51,  16.85
# t= 31.25 hours: v min/max  -3.74,   2.44 pv min/max -14.51,  16.85
# t= 31.50 hours: v min/max  -3.76,   2.46 pv min/max -14.51,  16.85
# t= 31.75 hours: v min/max  -3.78,   2.49 pv min/max -14.51,  16.85
# t= 32.00 hours: v min/max  -3.80,   2.52 pv min/max -14.51,  16.85
# t= 32.25 hours: v min/max  -3.81,   2.54 pv min/max -14.51,  16.85
# t= 32.50 hours: v min/max  -3.83,   2.56 pv min/max -14.51,  16.85
# t= 32.75 hours: v min/max  -3.84,   2.58 pv min/max -14.51,  16.85
# t= 33.00 hours: v min/max  -3.85,   2.61 pv min/max -14.51,  16.85
# t= 33.25 hours: v min/max  -3.86,   2.64 pv min/max -14.51,  16.85
# t= 33.50 hours: v min/max  -3.87,   2.67 pv min/max -14.51,  16.85
# t= 33.75 hours: v min/max  -3.88,   2.70 pv min/max -14.51,  16.85
# t= 34.00 hours: v min/max  -3.88,   2.72 pv min/max -14.51,  16.85
# t= 34.25 hours: v min/max  -3.89,   2.75 pv min/max -14.51,  16.85
# t= 34.50 hours: v min/max  -3.90,   2.78 pv min/max -14.51,  16.85
# t= 34.75 hours: v min/max  -3.90,   2.81 pv min/max -14.51,  16.85
# t= 35.00 hours: v min/max  -3.91,   2.84 pv min/max -14.51,  16.85
# t= 35.25 hours: v min/max  -3.91,   2.86 pv min/max -14.51,  16.85
# t= 35.50 hours: v min/max  -3.92,   2.88 pv min/max -14.51,  16.85
# t= 35.75 hours: v min/max  -3.93,   2.90 pv min/max -14.51,  16.85
# t= 36.00 hours: v min/max  -3.95,   2.93 pv min/max -14.51,  16.85
# t= 36.25 hours: v min/max  -3.97,   2.95 pv min/max -14.51,  16.85
# t= 36.50 hours: v min/max  -3.99,   2.97 pv min/max -14.51,  16.85
# t= 36.75 hours: v min/max  -4.01,   2.99 pv min/max -14.51,  16.85
# t= 37.00 hours: v min/max  -4.02,   3.02 pv min/max -14.51,  16.85
# t= 37.25 hours: v min/max  -4.04,   3.04 pv min/max -14.51,  16.85
# t= 37.50 hours: v min/max  -4.06,   3.06 pv min/max -14.51,  16.85
# t= 37.75 hours: v min/max  -4.07,   3.09 pv min/max -14.51,  16.85
# t= 38.00 hours: v min/max  -4.09,   3.12 pv min/max -14.51,  16.85
# t= 38.25 hours: v min/max  -4.10,   3.15 pv min/max -14.51,  16.85
# t= 38.50 hours: v min/max  -4.12,   3.18 pv min/max -14.51,  16.85
# t= 38.75 hours: v min/max  -4.14,   3.21 pv min/max -14.51,  16.85
# t= 39.00 hours: v min/max  -4.15,   3.24 pv min/max -14.51,  16.85
# t= 39.25 hours: v min/max  -4.17,   3.27 pv min/max -14.51,  16.85
# t= 39.50 hours: v min/max  -4.18,   3.30 pv min/max -14.51,  16.85
# t= 39.75 hours: v min/max  -4.20,   3.33 pv min/max -14.51,  16.85
# t= 40.00 hours: v min/max  -4.21,   3.36 pv min/max -14.51,  16.85
# t= 40.25 hours: v min/max  -4.22,   3.38 pv min/max -14.51,  16.85
# t= 40.50 hours: v min/max  -4.24,   3.41 pv min/max -14.51,  16.85
# t= 40.75 hours: v min/max  -4.27,   3.44 pv min/max -14.51,  16.85
# t= 41.00 hours: v min/max  -4.29,   3.46 pv min/max -14.51,  16.85
# t= 41.25 hours: v min/max  -4.32,   3.49 pv min/max -14.51,  16.85
# t= 41.50 hours: v min/max  -4.34,   3.51 pv min/max -14.51,  16.85
# t= 41.75 hours: v min/max  -4.36,   3.54 pv min/max -14.51,  16.85
# t= 42.00 hours: v min/max  -4.38,   3.56 pv min/max -14.51,  16.85
# t= 42.25 hours: v min/max  -4.40,   3.59 pv min/max -14.51,  16.85
# t= 42.50 hours: v min/max  -4.42,   3.62 pv min/max -14.51,  16.85
# t= 42.75 hours: v min/max  -4.44,   3.66 pv min/max -14.51,  16.85
# t= 43.00 hours: v min/max  -4.46,   3.70 pv min/max -14.51,  16.85
# t= 43.25 hours: v min/max  -4.48,   3.73 pv min/max -14.51,  16.85
# t= 43.50 hours: v min/max  -4.49,   3.76 pv min/max -14.51,  16.85
# t= 43.75 hours: v min/max  -4.51,   3.80 pv min/max -14.51,  16.85
# t= 44.00 hours: v min/max  -4.52,   3.83 pv min/max -14.51,  16.85
# t= 44.25 hours: v min/max  -4.54,   3.86 pv min/max -14.51,  16.85
# t= 44.50 hours: v min/max  -4.55,   3.89 pv min/max -14.51,  16.85
# t= 44.75 hours: v min/max  -4.56,   3.92 pv min/max -14.51,  16.85
# t= 45.00 hours: v min/max  -4.57,   3.94 pv min/max -14.51,  16.85
# t= 45.25 hours: v min/max  -4.58,   3.97 pv min/max -14.51,  16.85
# t= 45.50 hours: v min/max  -4.59,   4.00 pv min/max -14.51,  16.85
# t= 45.75 hours: v min/max  -4.61,   4.02 pv min/max -14.51,  16.85
# t= 46.00 hours: v min/max  -4.63,   4.05 pv min/max -14.51,  16.85
# t= 46.25 hours: v min/max  -4.66,   4.07 pv min/max -14.51,  16.85
# t= 46.50 hours: v min/max  -4.68,   4.09 pv min/max -14.51,  16.85
# t= 46.75 hours: v min/max  -4.71,   4.11 pv min/max -14.51,  16.85
# t= 47.00 hours: v min/max  -4.73,   4.13 pv min/max -14.51,  16.85
# t= 47.25 hours: v min/max  -4.75,   4.15 pv min/max -14.51,  16.85
# t= 47.50 hours: v min/max  -4.78,   4.18 pv min/max -14.51,  16.85
# t= 47.75 hours: v min/max  -4.80,   4.21 pv min/max -14.51,  16.85
# t= 48.00 hours: v min/max  -4.82,   4.24 pv min/max -14.51,  16.85
# t= 48.25 hours: v min/max  -4.84,   4.28 pv min/max -14.51,  16.85
# t= 48.50 hours: v min/max  -4.86,   4.31 pv min/max -14.52,  16.85
# t= 48.75 hours: v min/max  -4.88,   4.34 pv min/max -14.52,  16.85
# t= 49.00 hours: v min/max  -4.90,   4.37 pv min/max -14.52,  16.85
# t= 49.25 hours: v min/max  -4.91,   4.40 pv min/max -14.51,  16.85
# t= 49.50 hours: v min/max  -4.93,   4.43 pv min/max -14.51,  16.85
# t= 49.75 hours: v min/max  -4.95,   4.46 pv min/max -14.51,  16.85
# t= 50.00 hours: v min/max  -4.97,   4.49 pv min/max -14.51,  16.85
# t= 50.25 hours: v min/max  -4.98,   4.52 pv min/max -14.51,  16.85
# t= 50.50 hours: v min/max  -5.00,   4.55 pv min/max -14.51,  16.85
# t= 50.75 hours: v min/max  -5.04,   4.57 pv min/max -14.51,  16.85
# t= 51.00 hours: v min/max  -5.07,   4.60 pv min/max -14.51,  16.85
# t= 51.25 hours: v min/max  -5.11,   4.62 pv min/max -14.51,  16.85
# t= 51.50 hours: v min/max  -5.14,   4.65 pv min/max -14.51,  16.85
# t= 51.75 hours: v min/max  -5.18,   4.68 pv min/max -14.51,  16.85
# t= 52.00 hours: v min/max  -5.21,   4.70 pv min/max -14.51,  16.85
# t= 52.25 hours: v min/max  -5.24,   4.72 pv min/max -14.51,  16.85
# t= 52.50 hours: v min/max  -5.27,   4.75 pv min/max -14.51,  16.85
# t= 52.75 hours: v min/max  -5.30,   4.78 pv min/max -14.51,  16.85
# t= 53.00 hours: v min/max  -5.32,   4.82 pv min/max -14.51,  16.85
# t= 53.25 hours: v min/max  -5.35,   4.86 pv min/max -14.51,  16.85
# t= 53.50 hours: v min/max  -5.38,   4.90 pv min/max -14.51,  16.85
# t= 53.75 hours: v min/max  -5.41,   4.94 pv min/max -14.52,  16.85
# t= 54.00 hours: v min/max  -5.43,   4.98 pv min/max -14.52,  16.85
# t= 54.25 hours: v min/max  -5.46,   5.02 pv min/max -14.52,  16.85
# t= 54.50 hours: v min/max  -5.48,   5.06 pv min/max -14.52,  16.85
# t= 54.75 hours: v min/max  -5.50,   5.10 pv min/max -14.52,  16.85
# t= 55.00 hours: v min/max  -5.52,   5.13 pv min/max -14.52,  16.85
# t= 55.25 hours: v min/max  -5.54,   5.17 pv min/max -14.52,  16.85
# t= 55.50 hours: v min/max  -5.57,   5.20 pv min/max -14.52,  16.85
# t= 55.75 hours: v min/max  -5.60,   5.24 pv min/max -14.52,  16.85
# t= 56.00 hours: v min/max  -5.64,   5.27 pv min/max -14.52,  16.85
# t= 56.25 hours: v min/max  -5.67,   5.30 pv min/max -14.52,  16.85
# t= 56.50 hours: v min/max  -5.71,   5.33 pv min/max -14.52,  16.85
# t= 56.75 hours: v min/max  -5.74,   5.37 pv min/max -14.52,  16.85
# t= 57.00 hours: v min/max  -5.77,   5.40 pv min/max -14.51,  16.85
# t= 57.25 hours: v min/max  -5.81,   5.43 pv min/max -14.51,  16.85
# t= 57.50 hours: v min/max  -5.84,   5.46 pv min/max -14.51,  16.85
# t= 57.75 hours: v min/max  -5.88,   5.48 pv min/max -14.51,  16.85
# t= 58.00 hours: v min/max  -5.91,   5.52 pv min/max -14.51,  16.85
# t= 58.25 hours: v min/max  -5.94,   5.56 pv min/max -14.51,  16.85
# t= 58.50 hours: v min/max  -5.97,   5.61 pv min/max -14.52,  16.85
# t= 58.75 hours: v min/max  -5.99,   5.65 pv min/max -14.52,  16.85
# t= 59.00 hours: v min/max  -6.02,   5.69 pv min/max -14.52,  16.85
# t= 59.25 hours: v min/max  -6.05,   5.74 pv min/max -14.52,  16.85
# t= 59.50 hours: v min/max  -6.07,   5.78 pv min/max -14.52,  16.85
# t= 59.75 hours: v min/max  -6.10,   5.83 pv min/max -14.52,  16.85
# t= 60.00 hours: v min/max  -6.13,   5.87 pv min/max -14.52,  16.85
# t= 60.25 hours: v min/max  -6.17,   5.91 pv min/max -14.52,  16.85
# t= 60.50 hours: v min/max  -6.20,   5.95 pv min/max -14.52,  16.85
# t= 60.75 hours: v min/max  -6.23,   5.99 pv min/max -14.52,  16.85
# t= 61.00 hours: v min/max  -6.27,   6.03 pv min/max -14.52,  16.85
# t= 61.25 hours: v min/max  -6.30,   6.06 pv min/max -14.52,  16.85
# t= 61.50 hours: v min/max  -6.33,   6.10 pv min/max -14.52,  16.85
# t= 61.75 hours: v min/max  -6.38,   6.14 pv min/max -14.51,  16.85
# t= 62.00 hours: v min/max  -6.42,   6.18 pv min/max -14.51,  16.85
# t= 62.25 hours: v min/max  -6.46,   6.21 pv min/max -14.51,  16.85
# t= 62.50 hours: v min/max  -6.50,   6.24 pv min/max -14.51,  16.85
# t= 62.75 hours: v min/max  -6.54,   6.27 pv min/max -14.51,  16.85
# t= 63.00 hours: v min/max  -6.58,   6.30 pv min/max -14.51,  16.85
# t= 63.25 hours: v min/max  -6.61,   6.35 pv min/max -14.52,  16.85
# t= 63.50 hours: v min/max  -6.65,   6.40 pv min/max -14.52,  16.85
# t= 63.75 hours: v min/max  -6.68,   6.45 pv min/max -14.52,  16.85
# t= 64.00 hours: v min/max  -6.72,   6.51 pv min/max -14.52,  16.85
# t= 64.25 hours: v min/max  -6.76,   6.56 pv min/max -14.52,  16.85
# t= 64.50 hours: v min/max  -6.81,   6.61 pv min/max -14.52,  16.85
# t= 64.75 hours: v min/max  -6.86,   6.66 pv min/max -14.52,  16.85
# t= 65.00 hours: v min/max  -6.91,   6.70 pv min/max -14.52,  16.85
# t= 65.25 hours: v min/max  -6.96,   6.75 pv min/max -14.52,  16.85
# t= 65.50 hours: v min/max  -7.01,   6.80 pv min/max -14.52,  16.85
# t= 65.75 hours: v min/max  -7.05,   6.84 pv min/max -14.52,  16.85
# t= 66.00 hours: v min/max  -7.10,   6.89 pv min/max -14.52,  16.85
# t= 66.25 hours: v min/max  -7.14,   6.94 pv min/max -14.52,  16.85
# t= 66.50 hours: v min/max  -7.19,   6.98 pv min/max -14.52,  16.85
# t= 66.75 hours: v min/max  -7.23,   7.02 pv min/max -14.52,  16.85
# t= 67.00 hours: v min/max  -7.26,   7.07 pv min/max -14.52,  16.86
# t= 67.25 hours: v min/max  -7.30,   7.11 pv min/max -14.52,  16.86
# t= 67.50 hours: v min/max  -7.35,   7.14 pv min/max -14.52,  16.86
# t= 67.75 hours: v min/max  -7.39,   7.18 pv min/max -14.52,  16.86
# t= 68.00 hours: v min/max  -7.44,   7.22 pv min/max -14.52,  16.86
# t= 68.25 hours: v min/max  -7.48,   7.26 pv min/max -14.52,  16.86
# t= 68.50 hours: v min/max  -7.53,   7.32 pv min/max -14.52,  16.86
# t= 68.75 hours: v min/max  -7.57,   7.38 pv min/max -14.52,  16.86
# t= 69.00 hours: v min/max  -7.62,   7.44 pv min/max -14.52,  16.86
# t= 69.25 hours: v min/max  -7.68,   7.50 pv min/max -14.52,  16.86
# t= 69.50 hours: v min/max  -7.73,   7.56 pv min/max -14.52,  16.86
# t= 69.75 hours: v min/max  -7.79,   7.62 pv min/max -14.52,  16.86
# t= 70.00 hours: v min/max  -7.85,   7.68 pv min/max -14.52,  16.86
# t= 70.25 hours: v min/max  -7.90,   7.73 pv min/max -14.52,  16.86
# t= 70.50 hours: v min/max  -7.95,   7.79 pv min/max -14.52,  16.86
# t= 70.75 hours: v min/max  -8.00,   7.84 pv min/max -14.52,  16.86
# t= 71.00 hours: v min/max  -8.05,   7.89 pv min/max -14.52,  16.86
# t= 71.25 hours: v min/max  -8.10,   7.95 pv min/max -14.52,  16.86
# t= 71.50 hours: v min/max  -8.15,   8.00 pv min/max -14.52,  16.86
# t= 71.75 hours: v min/max  -8.19,   8.04 pv min/max -14.52,  16.86
# t= 72.00 hours: v min/max  -8.24,   8.09 pv min/max -14.52,  16.86
# t= 72.25 hours: v min/max  -8.28,   8.14 pv min/max -14.52,  16.86
# t= 72.50 hours: v min/max  -8.34,   8.18 pv min/max -14.52,  16.86
# t= 72.75 hours: v min/max  -8.39,   8.23 pv min/max -14.52,  16.86
# t= 73.00 hours: v min/max  -8.44,   8.27 pv min/max -14.52,  16.86
# t= 73.25 hours: v min/max  -8.50,   8.31 pv min/max -14.52,  16.87
# t= 73.50 hours: v min/max  -8.55,   8.37 pv min/max -14.52,  16.87
# t= 73.75 hours: v min/max  -8.60,   8.44 pv min/max -14.52,  16.87
# t= 74.00 hours: v min/max  -8.65,   8.51 pv min/max -14.52,  16.87
# t= 74.25 hours: v min/max  -8.72,   8.58 pv min/max -14.52,  16.87
# t= 74.50 hours: v min/max  -8.79,   8.65 pv min/max -14.52,  16.87
# t= 74.75 hours: v min/max  -8.86,   8.71 pv min/max -14.52,  16.87
# t= 75.00 hours: v min/max  -8.93,   8.78 pv min/max -14.52,  16.87
# t= 75.25 hours: v min/max  -9.00,   8.84 pv min/max -14.52,  16.88
# t= 75.50 hours: v min/max  -9.06,   8.91 pv min/max -14.52,  16.88
# t= 75.75 hours: v min/max  -9.12,   8.97 pv min/max -14.52,  16.88
# t= 76.00 hours: v min/max  -9.19,   9.03 pv min/max -14.52,  16.88
# t= 76.25 hours: v min/max  -9.25,   9.09 pv min/max -14.52,  16.88
# t= 76.50 hours: v min/max  -9.30,   9.15 pv min/max -14.52,  16.88
# t= 76.75 hours: v min/max  -9.36,   9.21 pv min/max -14.52,  16.89
# t= 77.00 hours: v min/max  -9.42,   9.27 pv min/max -14.52,  16.89
# t= 77.25 hours: v min/max  -9.48,   9.32 pv min/max -14.52,  16.89
# t= 77.50 hours: v min/max  -9.55,   9.38 pv min/max -14.53,  16.89
# t= 77.75 hours: v min/max  -9.61,   9.45 pv min/max -14.53,  16.89
# t= 78.00 hours: v min/max  -9.67,   9.52 pv min/max -14.53,  16.90
# t= 78.25 hours: v min/max  -9.73,   9.59 pv min/max -14.53,  16.90
# t= 78.50 hours: v min/max  -9.79,   9.67 pv min/max -14.54,  16.90
# t= 78.75 hours: v min/max  -9.85,   9.74 pv min/max -14.54,  16.90
# t= 79.00 hours: v min/max  -9.90,   9.81 pv min/max -14.54,  16.91
# t= 79.25 hours: v min/max  -9.97,   9.87 pv min/max -14.54,  16.91
# t= 79.50 hours: v min/max -10.05,   9.94 pv min/max -14.55,  16.91
# t= 79.75 hours: v min/max -10.12,  10.02 pv min/max -14.55,  16.91
# t= 80.00 hours: v min/max -10.20,  10.09 pv min/max -14.55,  16.91
# t= 80.25 hours: v min/max -10.27,  10.17 pv min/max -14.56,  16.92
# t= 80.50 hours: v min/max -10.35,  10.25 pv min/max -14.56,  16.92
# t= 80.75 hours: v min/max -10.42,  10.33 pv min/max -14.57,  16.92
# t= 81.00 hours: v min/max -10.48,  10.40 pv min/max -14.57,  16.92
# t= 81.25 hours: v min/max -10.55,  10.48 pv min/max -14.58,  16.93
# t= 81.50 hours: v min/max -10.61,  10.58 pv min/max -14.59,  16.93
# t= 81.75 hours: v min/max -10.69,  10.67 pv min/max -14.59,  16.93
# t= 82.00 hours: v min/max -10.77,  10.77 pv min/max -14.60,  16.94
# t= 82.25 hours: v min/max -10.84,  10.86 pv min/max -14.60,  16.94
# t= 82.50 hours: v min/max -10.92,  10.95 pv min/max -14.61,  16.94
# t= 82.75 hours: v min/max -10.99,  11.04 pv min/max -14.61,  16.94
# t= 83.00 hours: v min/max -11.06,  11.13 pv min/max -14.62,  16.95
# t= 83.25 hours: v min/max -11.12,  11.22 pv min/max -14.63,  16.95
# t= 83.50 hours: v min/max -11.18,  11.30 pv min/max -14.63,  16.95
# t= 83.75 hours: v min/max -11.24,  11.38 pv min/max -14.64,  16.95
# t= 84.00 hours: v min/max -11.30,  11.46 pv min/max -14.64,  16.96
# t= 84.25 hours: v min/max -11.36,  11.53 pv min/max -14.64,  16.96
# t= 84.50 hours: v min/max -11.41,  11.60 pv min/max -14.65,  16.97
# t= 84.75 hours: v min/max -11.48,  11.67 pv min/max -14.65,  16.97
# t= 85.00 hours: v min/max -11.56,  11.74 pv min/max -14.66,  16.97
# t= 85.25 hours: v min/max -11.64,  11.80 pv min/max -14.66,  16.98
# t= 85.50 hours: v min/max -11.73,  11.91 pv min/max -14.67,  16.98
# t= 85.75 hours: v min/max -11.83,  12.03 pv min/max -14.67,  16.99
# t= 86.00 hours: v min/max -11.92,  12.15 pv min/max -14.68,  17.00
# t= 86.25 hours: v min/max -12.01,  12.26 pv min/max -14.69,  17.01
# t= 86.50 hours: v min/max -12.10,  12.38 pv min/max -14.69,  17.02
# t= 86.75 hours: v min/max -12.19,  12.49 pv min/max -14.70,  17.03
# t= 87.00 hours: v min/max -12.28,  12.60 pv min/max -14.71,  17.04
# t= 87.25 hours: v min/max -12.37,  12.71 pv min/max -14.71,  17.05
# t= 87.50 hours: v min/max -12.45,  12.82 pv min/max -14.72,  17.06
# t= 87.75 hours: v min/max -12.53,  12.92 pv min/max -14.72,  17.07
# t= 88.00 hours: v min/max -12.61,  13.01 pv min/max -14.73,  17.09
# t= 88.25 hours: v min/max -12.68,  13.11 pv min/max -14.73,  17.12
# t= 88.50 hours: v min/max -12.76,  13.20 pv min/max -14.74,  17.14
# t= 88.75 hours: v min/max -12.83,  13.29 pv min/max -14.74,  17.16
# t= 89.00 hours: v min/max -12.90,  13.38 pv min/max -14.75,  17.19
# t= 89.25 hours: v min/max -12.98,  13.47 pv min/max -14.75,  17.21
# t= 89.50 hours: v min/max -13.10,  13.56 pv min/max -14.76,  17.23
# t= 89.75 hours: v min/max -13.21,  13.64 pv min/max -14.76,  17.26
# t= 90.00 hours: v min/max -13.32,  13.71 pv min/max -14.77,  17.28
# t= 90.25 hours: v min/max -13.43,  13.82 pv min/max -14.77,  17.30
# t= 90.50 hours: v min/max -13.53,  13.96 pv min/max -14.78,  17.32
# t= 90.75 hours: v min/max -13.63,  14.10 pv min/max -14.79,  17.34
# t= 91.00 hours: v min/max -13.73,  14.24 pv min/max -14.80,  17.36
# t= 91.25 hours: v min/max -13.82,  14.37 pv min/max -14.80,  17.38
# t= 91.50 hours: v min/max -13.92,  14.50 pv min/max -14.81,  17.40
# t= 91.75 hours: v min/max -14.07,  14.63 pv min/max -14.82,  17.42
# t= 92.00 hours: v min/max -14.23,  14.76 pv min/max -14.82,  17.44
# t= 92.25 hours: v min/max -14.39,  14.88 pv min/max -14.83,  17.45
# t= 92.50 hours: v min/max -14.54,  15.00 pv min/max -14.84,  17.48
# t= 92.75 hours: v min/max -14.70,  15.11 pv min/max -14.84,  17.51
# t= 93.00 hours: v min/max -14.85,  15.22 pv min/max -14.85,  17.54
# t= 93.25 hours: v min/max -15.00,  15.33 pv min/max -14.85,  17.57
# t= 93.50 hours: v min/max -15.15,  15.44 pv min/max -14.86,  17.60
# t= 93.75 hours: v min/max -15.29,  15.54 pv min/max -14.87,  17.63
# t= 94.00 hours: v min/max -15.43,  15.64 pv min/max -14.87,  17.66
# t= 94.25 hours: v min/max -15.57,  15.73 pv min/max -14.88,  17.68
# t= 94.50 hours: v min/max -15.70,  15.82 pv min/max -14.88,  17.71
# t= 94.75 hours: v min/max -15.83,  15.91 pv min/max -14.89,  17.74
# t= 95.00 hours: v min/max -15.95,  16.00 pv min/max -14.89,  17.76
# t= 95.25 hours: v min/max -16.07,  16.17 pv min/max -14.90,  17.79
# t= 95.50 hours: v min/max -16.19,  16.33 pv min/max -14.91,  17.81
# t= 95.75 hours: v min/max -16.30,  16.49 pv min/max -14.91,  17.83
# t= 96.00 hours: v min/max -16.41,  16.65 pv min/max -14.92,  17.85
# t= 96.25 hours: v min/max -16.53,  16.81 pv min/max -14.93,  17.87
# t= 96.50 hours: v min/max -16.72,  16.96 pv min/max -14.94,  17.89
# t= 96.75 hours: v min/max -16.91,  17.11 pv min/max -14.94,  17.91
# t= 97.00 hours: v min/max -17.10,  17.25 pv min/max -14.95,  17.94
# t= 97.25 hours: v min/max -17.29,  17.39 pv min/max -14.96,  17.98
# t= 97.50 hours: v min/max -17.47,  17.52 pv min/max -14.98,  18.01
# t= 97.75 hours: v min/max -17.65,  17.65 pv min/max -15.00,  18.05
# t= 98.00 hours: v min/max -17.82,  17.78 pv min/max -15.02,  18.08
# t= 98.25 hours: v min/max -18.00,  17.90 pv min/max -15.03,  18.12
# t= 98.50 hours: v min/max -18.16,  18.02 pv min/max -15.05,  18.15
# t= 98.75 hours: v min/max -18.33,  18.13 pv min/max -15.06,  18.19
# t= 99.00 hours: v min/max -18.48,  18.24 pv min/max -15.07,  18.22
# t= 99.25 hours: v min/max -18.64,  18.34 pv min/max -15.09,  18.25
# t= 99.50 hours: v min/max -18.78,  18.44 pv min/max -15.10,  18.29
# t= 99.75 hours: v min/max -18.93,  18.54 pv min/max -15.12,  18.32
# t=100.00 hours: v min/max -19.07,  18.72 pv min/max -15.15,  18.35
# t=100.25 hours: v min/max -19.20,  18.91 pv min/max -15.17,  18.38
# t=100.50 hours: v min/max -19.33,  19.10 pv min/max -15.20,  18.41
# t=100.75 hours: v min/max -19.46,  19.29 pv min/max -15.22,  18.44
# t=101.00 hours: v min/max -19.63,  19.47 pv min/max -15.25,  18.47
# t=101.25 hours: v min/max -19.86,  19.64 pv min/max -15.27,  18.49
# t=101.50 hours: v min/max -20.09,  19.81 pv min/max -15.29,  18.52
# t=101.75 hours: v min/max -20.31,  19.98 pv min/max -15.31,  18.57
# t=102.00 hours: v min/max -20.53,  20.15 pv min/max -15.33,  18.62
# t=102.25 hours: v min/max -20.74,  20.30 pv min/max -15.36,  18.66
# t=102.50 hours: v min/max -20.94,  20.46 pv min/max -15.38,  18.71
# t=102.75 hours: v min/max -21.14,  20.61 pv min/max -15.39,  18.75
# t=103.00 hours: v min/max -21.34,  20.75 pv min/max -15.41,  18.80
# t=103.25 hours: v min/max -21.54,  20.89 pv min/max -15.43,  18.84
# t=103.50 hours: v min/max -21.72,  21.02 pv min/max -15.44,  18.89
# t=103.75 hours: v min/max -21.91,  21.15 pv min/max -15.46,  18.93
# t=104.00 hours: v min/max -22.09,  21.27 pv min/max -15.50,  18.97
# t=104.25 hours: v min/max -22.26,  21.39 pv min/max -15.53,  19.01
# t=104.50 hours: v min/max -22.42,  21.49 pv min/max -15.56,  19.05
# t=104.75 hours: v min/max -22.58,  21.68 pv min/max -15.59,  19.09
# t=105.00 hours: v min/max -22.73,  21.91 pv min/max -15.62,  19.12
# t=105.25 hours: v min/max -22.87,  22.13 pv min/max -15.65,  19.16
# t=105.50 hours: v min/max -23.01,  22.35 pv min/max -15.68,  19.19
# t=105.75 hours: v min/max -23.25,  22.56 pv min/max -15.71,  19.22
# t=106.00 hours: v min/max -23.52,  22.77 pv min/max -15.74,  19.26
# t=106.25 hours: v min/max -23.78,  22.97 pv min/max -15.77,  19.32
# t=106.50 hours: v min/max -24.04,  23.17 pv min/max -15.79,  19.37
# t=106.75 hours: v min/max -24.29,  23.36 pv min/max -15.82,  19.43
# t=107.00 hours: v min/max -24.53,  23.54 pv min/max -15.84,  19.49
# t=107.25 hours: v min/max -24.77,  23.72 pv min/max -15.86,  19.54
# t=107.50 hours: v min/max -25.01,  23.89 pv min/max -15.88,  19.59
# t=107.75 hours: v min/max -25.24,  24.06 pv min/max -15.90,  19.64
# t=108.00 hours: v min/max -25.46,  24.22 pv min/max -15.94,  19.70
# t=108.25 hours: v min/max -25.68,  24.38 pv min/max -15.99,  19.74
# t=108.50 hours: v min/max -25.88,  24.52 pv min/max -16.03,  19.79
# t=108.75 hours: v min/max -26.08,  24.66 pv min/max -16.07,  19.84
# t=109.00 hours: v min/max -26.27,  24.79 pv min/max -16.11,  19.88
# t=109.25 hours: v min/max -26.46,  24.91 pv min/max -16.14,  19.93
# t=109.50 hours: v min/max -26.63,  25.08 pv min/max -16.18,  19.97
# t=109.75 hours: v min/max -26.80,  25.34 pv min/max -16.22,  20.01
# t=110.00 hours: v min/max -26.96,  25.60 pv min/max -16.25,  20.04
# t=110.25 hours: v min/max -27.12,  25.85 pv min/max -16.28,  20.09
# t=110.50 hours: v min/max -27.41,  26.10 pv min/max -16.31,  20.16
# t=110.75 hours: v min/max -27.73,  26.34 pv min/max -16.34,  20.23
# t=111.00 hours: v min/max -28.03,  26.57 pv min/max -16.37,  20.30
# t=111.25 hours: v min/max -28.33,  26.79 pv min/max -16.40,  20.36
# t=111.50 hours: v min/max -28.62,  27.01 pv min/max -16.42,  20.43
# t=111.75 hours: v min/max -28.91,  27.22 pv min/max -16.46,  20.49
# t=112.00 hours: v min/max -29.18,  27.42 pv min/max -16.51,  20.56
# t=112.25 hours: v min/max -29.45,  27.62 pv min/max -16.56,  20.62
# t=112.50 hours: v min/max -29.71,  27.80 pv min/max -16.61,  20.68
# t=112.75 hours: v min/max -29.96,  27.98 pv min/max -16.66,  20.74
# t=113.00 hours: v min/max -30.20,  28.15 pv min/max -16.70,  20.79
# t=113.25 hours: v min/max -30.44,  28.32 pv min/max -16.75,  20.85
# t=113.50 hours: v min/max -30.66,  28.47 pv min/max -16.79,  20.90
# t=113.75 hours: v min/max -30.88,  28.61 pv min/max -16.83,  20.95
# t=114.00 hours: v min/max -31.09,  28.75 pv min/max -16.87,  21.00
# t=114.25 hours: v min/max -31.28,  28.88 pv min/max -16.91,  21.04
# t=114.50 hours: v min/max -31.47,  29.13 pv min/max -16.95,  21.10
# t=114.75 hours: v min/max -31.65,  29.42 pv min/max -16.98,  21.18
# t=115.00 hours: v min/max -31.81,  29.70 pv min/max -17.01,  21.26
# t=115.25 hours: v min/max -32.12,  29.97 pv min/max -17.04,  21.34
# t=115.50 hours: v min/max -32.48,  30.23 pv min/max -17.07,  21.42
# t=115.75 hours: v min/max -32.84,  30.48 pv min/max -17.14,  21.50
# t=116.00 hours: v min/max -33.18,  30.73 pv min/max -17.20,  21.58
# t=116.25 hours: v min/max -33.51,  30.97 pv min/max -17.26,  21.65
# t=116.50 hours: v min/max -33.84,  31.20 pv min/max -17.32,  21.73
# t=116.75 hours: v min/max -34.15,  31.42 pv min/max -17.37,  21.80
# t=117.00 hours: v min/max -34.46,  31.63 pv min/max -17.43,  21.86
# t=117.25 hours: v min/max -34.75,  31.83 pv min/max -17.48,  21.93
# t=117.50 hours: v min/max -35.04,  32.02 pv min/max -17.53,  21.99
# t=117.75 hours: v min/max -35.31,  32.20 pv min/max -17.57,  22.05
# t=118.00 hours: v min/max -35.57,  32.36 pv min/max -17.62,  22.11
# t=118.25 hours: v min/max -35.82,  32.52 pv min/max -17.66,  22.16
# t=118.50 hours: v min/max -36.05,  32.67 pv min/max -17.70,  22.21
# t=118.75 hours: v min/max -36.28,  32.81 pv min/max -17.73,  22.25
# t=119.00 hours: v min/max -36.50,  32.94 pv min/max -17.76,  22.35
# t=119.25 hours: v min/max -36.70,  33.06 pv min/max -17.79,  22.45
# t=119.50 hours: v min/max -36.89,  33.25 pv min/max -17.87,  22.54
# t=119.75 hours: v min/max -37.07,  33.55 pv min/max -17.94,  22.63
# t=120.00 hours: v min/max -37.27,  33.83 pv min/max -18.01,  22.72
# t=120.25 hours: v min/max -37.68,  34.11 pv min/max -18.07,  22.80
# t=120.50 hours: v min/max -38.07,  34.37 pv min/max -18.14,  22.89
# t=120.75 hours: v min/max -38.45,  34.63 pv min/max -18.20,  22.97
# t=121.00 hours: v min/max -38.83,  34.88 pv min/max -18.26,  23.04
# t=121.25 hours: v min/max -39.18,  35.11 pv min/max -18.31,  23.11
# t=121.50 hours: v min/max -39.53,  35.34 pv min/max -18.36,  23.18
# t=121.75 hours: v min/max -39.86,  35.56 pv min/max -18.40,  23.25
# t=122.00 hours: v min/max -40.18,  35.76 pv min/max -18.45,  23.31
# t=122.25 hours: v min/max -40.48,  35.96 pv min/max -18.48,  23.37
# t=122.50 hours: v min/max -40.77,  36.14 pv min/max -18.51,  23.42
# t=122.75 hours: v min/max -41.05,  36.31 pv min/max -18.54,  23.47
# t=123.00 hours: v min/max -41.32,  36.47 pv min/max -18.58,  23.51
# t=123.25 hours: v min/max -41.57,  36.62 pv min/max -18.66,  23.60
# t=123.50 hours: v min/max -41.81,  36.77 pv min/max -18.74,  23.70
# t=123.75 hours: v min/max -42.03,  37.03 pv min/max -18.81,  23.81
# t=124.00 hours: v min/max -42.24,  37.31 pv min/max -18.88,  23.91
# t=124.25 hours: v min/max -42.43,  37.58 pv min/max -18.95,  24.00
# t=124.50 hours: v min/max -42.66,  37.84 pv min/max -19.01,  24.09
# t=124.75 hours: v min/max -43.03,  38.09 pv min/max -19.07,  24.18
# t=125.00 hours: v min/max -43.38,  38.33 pv min/max -19.12,  24.27
# t=125.25 hours: v min/max -43.72,  38.55 pv min/max -19.17,  24.35
# t=125.50 hours: v min/max -44.04,  38.77 pv min/max -19.21,  24.43
# t=125.75 hours: v min/max -44.35,  38.97 pv min/max -19.25,  24.50
# t=126.00 hours: v min/max -44.64,  39.15 pv min/max -19.28,  24.57
# t=126.25 hours: v min/max -44.92,  39.33 pv min/max -19.30,  24.64
# t=126.50 hours: v min/max -45.18,  39.49 pv min/max -19.32,  24.70
# t=126.75 hours: v min/max -45.46,  39.73 pv min/max -19.39,  24.75
# t=127.00 hours: v min/max -45.78,  40.11 pv min/max -19.47,  24.80
# t=127.25 hours: v min/max -46.09,  40.47 pv min/max -19.55,  24.84
# t=127.50 hours: v min/max -46.58,  40.82 pv min/max -19.63,  24.87
# t=127.75 hours: v min/max -47.08,  41.16 pv min/max -19.69,  24.90
# t=128.00 hours: v min/max -47.56,  41.48 pv min/max -19.76,  24.92
# t=128.25 hours: v min/max -48.03,  41.79 pv min/max -19.82,  25.01
# t=128.50 hours: v min/max -48.48,  42.09 pv min/max -19.87,  25.11
# t=128.75 hours: v min/max -48.91,  42.37 pv min/max -19.91,  25.20
# t=129.00 hours: v min/max -49.33,  42.64 pv min/max -19.95,  25.28
# t=129.25 hours: v min/max -49.72,  42.90 pv min/max -19.98,  25.36
# t=129.50 hours: v min/max -50.10,  43.14 pv min/max -20.01,  25.44
# t=129.75 hours: v min/max -50.46,  43.37 pv min/max -20.03,  25.51
# t=130.00 hours: v min/max -50.81,  43.58 pv min/max -20.04,  25.57
# t=130.25 hours: v min/max -51.14,  43.78 pv min/max -20.04,  25.62
# t=130.50 hours: v min/max -51.44,  43.96 pv min/max -20.13,  25.67
# t=130.75 hours: v min/max -51.73,  44.12 pv min/max -20.20,  25.71
# t=131.00 hours: v min/max -52.00,  44.28 pv min/max -20.28,  25.74
# t=131.25 hours: v min/max -52.25,  44.64 pv min/max -20.34,  25.76
# t=131.50 hours: v min/max -52.48,  45.10 pv min/max -20.40,  25.78
# t=131.75 hours: v min/max -52.70,  45.55 pv min/max -20.45,  25.78
# t=132.00 hours: v min/max -52.89,  45.99 pv min/max -20.50,  25.78
# t=132.25 hours: v min/max -53.11,  46.42 pv min/max -20.54,  25.76
# t=132.50 hours: v min/max -53.61,  46.84 pv min/max -20.57,  25.74
# t=132.75 hours: v min/max -54.09,  47.25 pv min/max -20.59,  25.71
# t=133.00 hours: v min/max -54.55,  47.64 pv min/max -20.61,  25.66
# t=133.25 hours: v min/max -54.99,  48.02 pv min/max -20.61,  25.61
# t=133.50 hours: v min/max -55.41,  48.38 pv min/max -20.61,  25.55
# t=133.75 hours: v min/max -55.82,  48.73 pv min/max -20.60,  25.47
# t=134.00 hours: v min/max -56.20,  49.07 pv min/max -20.64,  25.39
# t=134.25 hours: v min/max -56.56,  49.39 pv min/max -20.69,  25.29
# t=134.50 hours: v min/max -56.90,  49.69 pv min/max -20.74,  25.19
# t=134.75 hours: v min/max -57.22,  49.98 pv min/max -20.80,  25.12
# t=135.00 hours: v min/max -57.53,  50.26 pv min/max -20.89,  25.07
# t=135.25 hours: v min/max -57.81,  50.52 pv min/max -20.98,  25.02
# t=135.50 hours: v min/max -58.07,  50.93 pv min/max -21.07,  24.95
# t=135.75 hours: v min/max -58.31,  51.43 pv min/max -21.15,  24.87
# t=136.00 hours: v min/max -58.53,  51.92 pv min/max -21.24,  24.78
# t=136.25 hours: v min/max -58.73,  52.39 pv min/max -21.32,  24.67
# t=136.50 hours: v min/max -58.92,  52.84 pv min/max -21.39,  24.56
# t=136.75 hours: v min/max -59.08,  53.28 pv min/max -21.47,  24.43
# t=137.00 hours: v min/max -59.23,  53.69 pv min/max -21.54,  24.30
# t=137.25 hours: v min/max -59.36,  54.09 pv min/max -21.61,  24.15
# t=137.50 hours: v min/max -59.47,  54.47 pv min/max -21.68,  23.99
# t=137.75 hours: v min/max -59.56,  54.82 pv min/max -21.74,  23.82
# t=138.00 hours: v min/max -59.91,  55.16 pv min/max -21.80,  23.63
# t=138.25 hours: v min/max -60.29,  55.48 pv min/max -21.86,  23.44
# t=138.50 hours: v min/max -60.65,  55.79 pv min/max -21.91,  23.50
# t=138.75 hours: v min/max -61.00,  56.07 pv min/max -21.96,  23.69
# t=139.00 hours: v min/max -61.33,  56.57 pv min/max -22.00,  23.87
# t=139.25 hours: v min/max -61.63,  57.19 pv min/max -22.04,  24.03
# t=139.50 hours: v min/max -61.92,  57.80 pv min/max -22.07,  24.16
# t=139.75 hours: v min/max -62.20,  58.38 pv min/max -22.10,  24.44
# t=140.00 hours: v min/max -62.45,  58.94 pv min/max -22.13,  24.77
# t=140.25 hours: v min/max -62.69,  59.49 pv min/max -22.18,  25.11
# t=140.50 hours: v min/max -62.91,  60.01 pv min/max -22.24,  25.44
# t=140.75 hours: v min/max -63.11,  60.51 pv min/max -22.30,  25.78
# t=141.00 hours: v min/max -63.30,  60.99 pv min/max -22.35,  26.12
# t=141.25 hours: v min/max -63.46,  61.45 pv min/max -22.40,  26.45
# t=141.50 hours: v min/max -63.61,  61.89 pv min/max -22.45,  26.78
# t=141.75 hours: v min/max -63.74,  62.31 pv min/max -22.49,  27.11
# t=142.00 hours: v min/max -63.86,  62.70 pv min/max -22.52,  27.43
# t=142.25 hours: v min/max -63.96,  63.08 pv min/max -22.55,  27.75
# t=142.50 hours: v min/max -64.10,  63.43 pv min/max -22.59,  28.06
# t=142.75 hours: v min/max -64.64,  63.76 pv min/max -22.95,  28.36
# t=143.00 hours: v min/max -65.15,  64.07 pv min/max -23.30,  28.64
# t=143.25 hours: v min/max -65.63,  64.36 pv min/max -23.65,  28.92
# t=143.50 hours: v min/max -66.07,  64.62 pv min/max -23.99,  29.18
# t=143.75 hours: v min/max -66.47,  64.86 pv min/max -24.32,  29.43
# t=144.00 hours: v min/max -66.83,  65.41 pv min/max -24.64,  29.67
# t=144.25 hours: v min/max -67.14,  66.24 pv min/max -24.95,  29.88
# t=144.50 hours: v min/max -67.41,  67.05 pv min/max -25.32,  30.08
# t=144.75 hours: v min/max -67.64,  67.83 pv min/max -25.76,  30.26
# t=145.00 hours: v min/max -67.81,  68.59 pv min/max -26.19,  30.42
# t=145.25 hours: v min/max -68.17,  69.31 pv min/max -26.60,  30.55
# t=145.50 hours: v min/max -68.64,  70.01 pv min/max -26.99,  30.67
# t=145.75 hours: v min/max -69.06,  70.67 pv min/max -27.35,  30.76
# t=146.00 hours: v min/max -69.45,  71.29 pv min/max -27.67,  30.83
# t=146.25 hours: v min/max -69.79,  71.88 pv min/max -27.96,  30.87
# t=146.50 hours: v min/max -70.08,  72.42 pv min/max -28.20,  30.90
# t=146.75 hours: v min/max -70.31,  72.91 pv min/max -28.39,  30.90
# t=147.00 hours: v min/max -70.50,  73.36 pv min/max -28.53,  30.87
# t=147.25 hours: v min/max -70.63,  73.75 pv min/max -28.61,  30.82
# t=147.50 hours: v min/max -70.71,  74.10 pv min/max -28.63,  30.75
# t=147.75 hours: v min/max -70.73,  74.39 pv min/max -28.58,  30.65
# t=148.00 hours: v min/max -70.69,  74.62 pv min/max -28.59,  30.54
# t=148.25 hours: v min/max -70.71,  74.79 pv min/max -28.61,  30.39
# t=148.50 hours: v min/max -71.11,  74.91 pv min/max -28.56,  30.23
# t=148.75 hours: v min/max -71.47,  74.96 pv min/max -28.44,  30.05
# t=149.00 hours: v min/max -71.77,  75.20 pv min/max -28.25,  29.85
# t=149.25 hours: v min/max -72.02,  75.82 pv min/max -27.98,  29.62
# t=149.50 hours: v min/max -72.22,  76.40 pv min/max -27.65,  29.38
# t=149.75 hours: v min/max -72.37,  76.93 pv min/max -27.25,  29.12
# t=150.00 hours: v min/max -72.47,  77.41 pv min/max -26.79,  28.84
# t=150.25 hours: v min/max -72.51,  77.84 pv min/max -26.27,  28.67
# t=150.50 hours: v min/max -72.50,  78.21 pv min/max -25.71,  29.15
# t=150.75 hours: v min/max -72.44,  78.54 pv min/max -25.10,  29.56
# t=151.00 hours: v min/max -72.33,  78.81 pv min/max -24.46,  29.90
# t=151.25 hours: v min/max -72.17,  79.03 pv min/max -23.79,  30.15
# t=151.50 hours: v min/max -71.96,  79.20 pv min/max -23.09,  30.32
# t=151.75 hours: v min/max -72.15,  79.31 pv min/max -23.10,  30.38
# t=152.00 hours: v min/max -72.80,  79.37 pv min/max -23.12,  30.70
# t=152.25 hours: v min/max -73.42,  79.38 pv min/max -23.13,  30.96
# t=152.50 hours: v min/max -74.03,  79.34 pv min/max -23.49,  31.11
# t=152.75 hours: v min/max -74.61,  79.74 pv min/max -24.03,  31.14
# t=153.00 hours: v min/max -75.16,  80.10 pv min/max -24.55,  31.05
# t=153.25 hours: v min/max -75.70,  80.41 pv min/max -25.04,  30.82
# t=153.50 hours: v min/max -76.20,  80.67 pv min/max -25.50,  30.48
# t=153.75 hours: v min/max -76.69,  80.88 pv min/max -25.93,  30.40
# t=154.00 hours: v min/max -77.15,  81.04 pv min/max -26.34,  30.18
# t=154.25 hours: v min/max -77.59,  81.16 pv min/max -26.81,  29.84
# t=154.50 hours: v min/max -78.00,  81.23 pv min/max -27.23,  29.36
# t=154.75 hours: v min/max -78.39,  81.25 pv min/max -27.58,  29.33
# t=155.00 hours: v min/max -78.76,  81.24 pv min/max -27.88,  29.53
# t=155.25 hours: v min/max -79.10,  81.18 pv min/max -28.10,  29.70
# t=155.50 hours: v min/max -79.42,  81.07 pv min/max -28.26,  29.84
# t=155.75 hours: v min/max -79.71,  80.93 pv min/max -28.33,  29.93
# t=156.00 hours: v min/max -79.97,  80.76 pv min/max -28.33,  29.99
# t=156.25 hours: v min/max -80.20,  80.55 pv min/max -28.26,  30.01
# t=156.50 hours: v min/max -80.41,  80.31 pv min/max -28.11,  30.00
# t=156.75 hours: v min/max -80.59,  80.04 pv min/max -27.88,  29.96
# t=157.00 hours: v min/max -80.75,  79.74 pv min/max -27.59,  29.93
# t=157.25 hours: v min/max -81.20,  79.83 pv min/max -27.23,  29.87
# t=157.50 hours: v min/max -81.71,  80.00 pv min/max -26.81,  29.77
# t=157.75 hours: v min/max -82.19,  80.15 pv min/max -26.34,  29.64
# t=158.00 hours: v min/max -82.64,  80.27 pv min/max -25.83,  30.10
# t=158.25 hours: v min/max -83.06,  80.37 pv min/max -25.27,  30.94
# t=158.50 hours: v min/max -83.44,  80.45 pv min/max -25.15,  31.70
# t=158.75 hours: v min/max -83.80,  80.52 pv min/max -25.13,  32.35
# t=159.00 hours: v min/max -84.13,  80.57 pv min/max -25.35,  32.89
# t=159.25 hours: v min/max -84.42,  80.60 pv min/max -25.94,  33.29
# t=159.50 hours: v min/max -84.69,  80.62 pv min/max -26.46,  33.74
# t=159.75 hours: v min/max -84.93,  80.62 pv min/max -26.91,  34.32
# t=160.00 hours: v min/max -85.13,  80.62 pv min/max -27.27,  34.73
# t=160.25 hours: v min/max -85.30,  80.60 pv min/max -27.54,  34.96
# t=160.50 hours: v min/max -85.44,  80.82 pv min/max -27.72,  35.01
# t=160.75 hours: v min/max -85.55,  81.02 pv min/max -27.78,  34.94
# t=161.00 hours: v min/max -85.63,  81.18 pv min/max -27.75,  35.14
# t=161.25 hours: v min/max -85.68,  81.31 pv min/max -27.62,  35.28
# t=161.50 hours: v min/max -85.70,  81.39 pv min/max -27.96,  35.35
# t=161.75 hours: v min/max -85.69,  81.45 pv min/max -28.47,  35.37
# t=162.00 hours: v min/max -85.65,  81.46 pv min/max -28.89,  35.32
# t=162.25 hours: v min/max -85.66,  81.43 pv min/max -29.22,  35.20
# t=162.50 hours: v min/max -85.74,  81.36 pv min/max -29.45,  35.02
# t=162.75 hours: v min/max -85.86,  81.41 pv min/max -29.59,  34.78
# t=163.00 hours: v min/max -86.26,  81.50 pv min/max -29.62,  34.48
# t=163.25 hours: v min/max -86.63,  81.55 pv min/max -29.55,  34.12
# t=163.50 hours: v min/max -86.97,  81.55 pv min/max -29.38,  33.70
# t=163.75 hours: v min/max -87.29,  81.49 pv min/max -29.12,  33.23
# t=164.00 hours: v min/max -87.58,  81.49 pv min/max -28.76,  33.00
# t=164.25 hours: v min/max -87.85,  81.81 pv min/max -28.32,  32.76
# t=164.50 hours: v min/max -88.09,  82.08 pv min/max -27.82,  32.48
# t=164.75 hours: v min/max -88.31,  82.30 pv min/max -27.24,  32.59
# t=165.00 hours: v min/max -88.50,  82.49 pv min/max -26.66,  33.55
# t=165.25 hours: v min/max -88.66,  82.64 pv min/max -26.55,  34.50
# t=165.50 hours: v min/max -88.80,  82.74 pv min/max -26.37,  35.43
# t=165.75 hours: v min/max -88.91,  82.79 pv min/max -26.12,  36.33
# t=166.00 hours: v min/max -88.99,  82.80 pv min/max -26.13,  37.19
# t=166.25 hours: v min/max -89.05,  82.77 pv min/max -26.00,  38.00
# t=166.50 hours: v min/max -89.08,  82.85 pv min/max -26.26,  38.75
# t=166.75 hours: v min/max -89.08,  83.32 pv min/max -26.37,  39.44
# t=167.00 hours: v min/max -89.05,  83.84 pv min/max -26.33,  40.05
# t=167.25 hours: v min/max -89.00,  84.34 pv min/max -26.71,  40.57
# t=167.50 hours: v min/max -88.91,  84.81 pv min/max -27.05,  41.01
# t=167.75 hours: v min/max -88.80,  85.26 pv min/max -27.36,  41.35
# t=168.00 hours: v min/max -88.66,  85.68 pv min/max -27.61,  41.58
# t=168.25 hours: v min/max -88.50,  86.07 pv min/max -27.82,  41.71
# t=168.50 hours: v min/max -88.50,  86.43 pv min/max -27.97,  41.73
# t=168.75 hours: v min/max -88.54,  86.77 pv min/max -28.08,  41.65
# t=169.00 hours: v min/max -88.56,  87.09 pv min/max -28.22,  41.46
# t=169.25 hours: v min/max -88.76,  87.37 pv min/max -28.50,  41.16
# t=169.50 hours: v min/max -89.07,  87.63 pv min/max -28.73,  40.78
# t=169.75 hours: v min/max -89.36,  87.86 pv min/max -28.90,  40.42
# t=170.00 hours: v min/max -89.62,  88.07 pv min/max -29.01,  40.85
# t=170.25 hours: v min/max -89.85,  88.24 pv min/max -29.07,  41.27
# t=170.50 hours: v min/max -90.05,  88.42 pv min/max -29.06,  41.68
# t=170.75 hours: v min/max -90.22,  88.97 pv min/max -29.00,  42.06
# t=171.00 hours: v min/max -90.37,  89.50 pv min/max -28.87,  42.43
# t=171.25 hours: v min/max -90.48,  90.00 pv min/max -28.69,  42.77
# t=171.50 hours: v min/max -90.57,  90.46 pv min/max -28.46,  43.10
# t=171.75 hours: v min/max -90.63,  90.89 pv min/max -28.17,  43.41
# t=172.00 hours: v min/max -90.66,  91.30 pv min/max -27.83,  43.70
# t=172.25 hours: v min/max -90.66,  91.67 pv min/max -27.45,  43.96
# t=172.50 hours: v min/max -90.64,  92.01 pv min/max -27.15,  44.21
# t=172.75 hours: v min/max -90.59,  92.33 pv min/max -27.45,  44.43
# t=173.00 hours: v min/max -90.51,  92.62 pv min/max -27.73,  44.64
# t=173.25 hours: v min/max -90.40,  92.88 pv min/max -27.98,  44.81
# t=173.50 hours: v min/max -90.39,  93.12 pv min/max -28.22,  44.97
# t=173.75 hours: v min/max -90.35,  93.32 pv min/max -28.42,  45.10
# t=174.00 hours: v min/max -90.29,  93.51 pv min/max -28.60,  45.20
# t=174.25 hours: v min/max -90.35,  93.66 pv min/max -28.74,  45.28
# t=174.50 hours: v min/max -90.45,  93.80 pv min/max -28.85,  45.32
# t=174.75 hours: v min/max -90.53,  93.91 pv min/max -28.92,  45.34
# t=175.00 hours: v min/max -90.61,  93.99 pv min/max -28.95,  45.32
# t=175.25 hours: v min/max -90.68,  94.06 pv min/max -28.94,  45.27
# t=175.50 hours: v min/max -90.74,  94.11 pv min/max -29.32,  45.18
# t=175.75 hours: v min/max -90.79,  94.13 pv min/max -29.81,  45.35
# t=176.00 hours: v min/max -90.83,  94.14 pv min/max -30.26,  45.49
# t=176.25 hours: v min/max -90.85,  94.13 pv min/max -30.66,  45.58
# t=176.50 hours: v min/max -90.90,  94.10 pv min/max -31.00,  45.63
# t=176.75 hours: v min/max -91.05,  94.05 pv min/max -31.29,  45.64
# t=177.00 hours: v min/max -91.27,  93.99 pv min/max -31.52,  45.60
# t=177.25 hours: v min/max -91.46,  93.98 pv min/max -31.68,  45.51
# t=177.50 hours: v min/max -91.63,  94.09 pv min/max -31.78,  45.37
# t=177.75 hours: v min/max -91.77,  94.36 pv min/max -31.80,  45.18
# t=178.00 hours: v min/max -91.90,  94.59 pv min/max -31.75,  44.94
# t=178.25 hours: v min/max -92.01,  94.79 pv min/max -31.63,  44.65
# t=178.50 hours: v min/max -92.09,  94.96 pv min/max -31.44,  44.31
# t=178.75 hours: v min/max -92.16,  95.10 pv min/max -31.18,  43.93
# t=179.00 hours: v min/max -92.20,  95.22 pv min/max -30.85,  43.51
# t=179.25 hours: v min/max -92.23,  95.31 pv min/max -30.46,  43.04
# t=179.50 hours: v min/max -92.24,  95.38 pv min/max -30.02,  43.49
# t=179.75 hours: v min/max -92.22,  95.42 pv min/max -30.28,  44.88
# t=180.00 hours: v min/max -92.19,  95.45 pv min/max -30.96,  46.18
# t=180.25 hours: v min/max -92.14,  95.46 pv min/max -31.51,  47.37
# t=180.50 hours: v min/max -92.07,  95.44 pv min/max -31.92,  48.43
# t=180.75 hours: v min/max -91.98,  95.42 pv min/max -32.16,  49.34
# t=181.00 hours: v min/max -92.11,  95.38 pv min/max -32.24,  50.07
# t=181.25 hours: v min/max -92.45,  95.32 pv min/max -32.13,  50.61
# t=181.50 hours: v min/max -92.78,  95.44 pv min/max -31.86,  50.93
# t=181.75 hours: v min/max -93.08,  95.58 pv min/max -31.42,  51.03
# t=182.00 hours: v min/max -93.37,  95.70 pv min/max -31.04,  50.89
# t=182.25 hours: v min/max -93.63,  95.81 pv min/max -31.86,  50.51
# t=182.50 hours: v min/max -93.88,  95.91 pv min/max -32.67,  49.91
# t=182.75 hours: v min/max -94.12,  96.00 pv min/max -33.46,  49.08
# t=183.00 hours: v min/max -94.33,  96.08 pv min/max -34.23,  48.82
# t=183.25 hours: v min/max -94.54,  96.15 pv min/max -34.98,  49.05
# t=183.50 hours: v min/max -94.74,  96.21 pv min/max -35.68,  49.04
# t=183.75 hours: v min/max -94.92,  96.25 pv min/max -36.34,  48.78
# t=184.00 hours: v min/max -95.10,  96.29 pv min/max -36.95,  48.28
# t=184.25 hours: v min/max -95.27,  96.32 pv min/max -37.50,  47.52
# t=184.50 hours: v min/max -95.43,  96.34 pv min/max -37.97,  46.53
# t=184.75 hours: v min/max -95.58,  96.35 pv min/max -38.35,  45.33
# t=185.00 hours: v min/max -95.72,  96.35 pv min/max -38.65,  45.30
# t=185.25 hours: v min/max -95.86,  96.34 pv min/max -38.84,  46.81
# t=185.50 hours: v min/max -95.99,  96.32 pv min/max -38.91,  48.21
# t=185.75 hours: v min/max -96.18,  96.30 pv min/max -38.87,  49.47
# t=186.00 hours: v min/max -96.43,  96.27 pv min/max -38.71,  52.01
# t=186.25 hours: v min/max -96.66,  96.23 pv min/max -38.42,  54.66
# t=186.50 hours: v min/max -96.88,  96.20 pv min/max -38.01,  57.31
# t=186.75 hours: v min/max -97.09,  96.15 pv min/max -37.47,  59.89
# t=187.00 hours: v min/max -97.28,  96.10 pv min/max -36.82,  62.33
# t=187.25 hours: v min/max -97.46,  96.04 pv min/max -36.61,  64.58
# t=187.50 hours: v min/max -97.62,  95.97 pv min/max -38.86,  66.54
# t=187.75 hours: v min/max -97.77,  95.90 pv min/max -41.30,  68.15
# t=188.00 hours: v min/max -97.91,  95.82 pv min/max -43.98,  69.31
# t=188.25 hours: v min/max -98.03,  95.97 pv min/max -46.90,  71.85
# t=188.50 hours: v min/max -98.14,  96.12 pv min/max -50.07,  74.94
# t=188.75 hours: v min/max -98.24,  96.27 pv min/max -53.51,  77.65
# t=189.00 hours: v min/max -98.32,  96.40 pv min/max -57.22,  79.85
# t=189.25 hours: v min/max -98.39,  96.52 pv min/max -61.19,  81.41
# t=189.50 hours: v min/max -98.44,  96.62 pv min/max -65.41,  82.23
# t=189.75 hours: v min/max -98.49,  96.71 pv min/max -69.82,  82.24
# t=190.00 hours: v min/max -98.53,  96.78 pv min/max -74.34,  81.42
# t=190.25 hours: v min/max -98.55,  96.84 pv min/max -78.88,  79.81
# t=190.50 hours: v min/max -98.57,  96.89 pv min/max -83.27,  78.41
# t=190.75 hours: v min/max -98.58,  96.92 pv min/max -87.34,  78.45
# t=191.00 hours: v min/max -98.58,  96.93 pv min/max -90.83,  77.70
# t=191.25 hours: v min/max -98.58,  96.93 pv min/max -93.51,  76.19
# t=191.50 hours: v min/max -98.57,  96.91 pv min/max -95.16,  74.00
# t=191.75 hours: v min/max -98.55,  96.88 pv min/max -96.58,  71.24
# t=192.00 hours: v min/max -98.53,  96.83 pv min/max -97.64,  68.02
# CPU time =  6.76254
# max/min upper layer thk 75.86395 13847.516
